# %%
import pandas as pd

# %%
x=pd.read_csv('Downloads\\bank_client_information.csv')
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x.head(2)
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0     5000.0
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K    10000.0
#
#    Years with Bank
# 0                5
# 1                6

# %%
x.tail(2)
# Out:
#   First Name Last Name              Email Postal Code  Net Worth  \
# 8     Joseph    Patton     daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran  guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 8                1
# 9               13

# %%
x[['Last Name','Email','Net Worth']]
# Out:
#   Last Name                    Email  Net Worth
# 0     Steve           bird@gmail.com    5000.00
# 1     Small       nsmall@hotmail.com   10000.00
# 2    Keller          azikez@gahew.mr    9072.02
# 3     Steve         chanel@gmail.com   11072.02
# 4      Noor         kate@hotmail.com    5000.00
# 5        Mo          samer@gmail.com  100000.00
# 6    Ismail  heba.ismail@hotmail.com   50000.00
# 7     Ahmed      Laila.a@hotmail.com   20000.00
# 8    Patton           daafeja@boh.jm    2629.13
# 9     Moran        guutodi@bigwoc.kw    8626.96

# %%
df = pd.read_html('https://www.livingin-canada.com/house-prices-canada.html')
df
# Out:
# [                                                City  \
#  0                                      Vancouver, BC
#  1                                       Toronto, Ont
#  2                                        Ottawa, Ont
#  3                                       Calgary, Alb
#  4                                      Montreal, Que
#  5                                        Halifax, NS
#  6                                       Regina, Sask
#  7                                    Fredericton, NB
#  8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
#  0                                         $1,036,000
#  1                                           $870,000
#  2                                           $479,000
#  3                                           $410,000
#  4                                           $435,000
#  5                                           $331,000
# ...

# %%
df[0]
# Out:
#                                                 City  \
# 0                                      Vancouver, BC
# 1                                       Toronto, Ont
# 2                                        Ottawa, Ont
# 3                                       Calgary, Alb
# 4                                      Montreal, Que
# 5                                        Halifax, NS
# 6                                       Regina, Sask
# 7                                    Fredericton, NB
# 8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                  Average House Price  \
# 0                                         $1,036,000
# 1                                           $870,000
# 2                                           $479,000
# 3                                           $410,000
# 4                                           $435,000
# 5                                           $331,000
# 6                                           $254,000
# ...

# %%
df[1]
# Out:
#                                              Province  \
# 0                                    British Columbia
# 1                                             Ontario
# 2                                             Alberta
# 3                                              Quebec
# 4                                            Manitoba
# 5                                        Saskatchewan
# 6                                         Nova Scotia
# 7                                Prince Edward Island
# 8                             Newfoundland / Labrador
# 9                                       New Brunswick
# 10                                   Canadian Average
# 11  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
# 0                                            $736,000
# 1                                            $594,000
# 2                                            $353,000
# ...

# %%
x=pd.read_csv('Downloads\\bank_client_information.csv')
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x.to_csv("My pandas file",index=False)
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %% [markdown]
# # Setting Resetting index

# %%
x.set_index('Net Worth',inplace = True)

# %%
x
# Out:
#           First Name Last Name                    Email Postal Code  \
# Net Worth
# 5000.00        Bird      Steve           bird@gmail.com     N94 3M0
# 10000.00        Noah     Small       nsmall@hotmail.com     N8S 14K
# 9072.02         Nina    Keller          azikez@gahew.mr     S1T 4E6
# 11072.02     Chanel      Steve         chanel@gmail.com     N7T 3E6
# 5000.00         Kate      Noor         kate@hotmail.com     K8N 5H6
# 100000.00      Samer        Mo          samer@gmail.com     J7H 3HY
# 50000.00        Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8
# 20000.00       Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0
# 2629.13       Joseph    Patton           daafeja@boh.jm     M6U 5U7
# 8626.96         Noah     Moran        guutodi@bigwoc.kw     K2D 4M9
#
#            Years with Bank
# Net Worth
# 5000.00                  5
# 10000.00                 6
# 9072.02                  7
# 11072.02                10
# 5000.00                 22
# ...

# %%
x.reset_index(inplace =True)
x
# Out:
#    Net Worth First Name Last Name                    Email Postal Code  \
# 0    5000.00      Bird      Steve           bird@gmail.com     N94 3M0
# 1   10000.00       Noah     Small       nsmall@hotmail.com     N8S 14K
# 2    9072.02       Nina    Keller          azikez@gahew.mr     S1T 4E6
# 3   11072.02    Chanel      Steve         chanel@gmail.com     N7T 3E6
# 4    5000.00       Kate      Noor         kate@hotmail.com     K8N 5H6
# 5  100000.00      Samer        Mo          samer@gmail.com     J7H 3HY
# 6   50000.00       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8
# 7   20000.00      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0
# 8    2629.13     Joseph    Patton           daafeja@boh.jm     M6U 5U7
# 9    8626.96       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %% [markdown]
# # MINI CHALLENGE #4:
#
# # Load the bank_client_information.csv and then set the "Last Name" column as the index

# %%
x=pd.read_csv('Downloads\\bank_client_information.csv')
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x.set_index("Last Name")
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#            Years with Bank
# Last Name
# Steve                    5
# Small                    6
# Keller                   7
# Steve                   10
# Noor                    22
# ...

# %% [markdown]
# # Selecting columns from the dataframe

# %%
x=pd.read_csv('Downloads\\bank_client_information.csv')
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x.Email
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
b=x['Last Name']
b
# Out:
# 0     Steve
# 1     Small
# 2    Keller
# 3     Steve
# 4      Noor
# 5        Mo
# 6    Ismail
# 7     Ahmed
# 8    Patton
# 9     Moran
# Name: Last Name, dtype: object

# %%
x["First Name"]
# Out:
# 0      Bird
# 1       Noah
# 2       Nina
# 3    Chanel
# 4       Kate
# 5      Samer
# 6       Heba
# 7      Laila
# 8     Joseph
# 9       Noah
# Name: First Name, dtype: object

# %%
x[["First Name","Last Name","Net Worth"]]
# Out:
#   First Name Last Name  Net Worth
# 0      Bird      Steve    5000.00
# 1       Noah     Small   10000.00
# 2       Nina    Keller    9072.02
# 3    Chanel      Steve   11072.02
# 4       Kate      Noor    5000.00
# 5      Samer        Mo  100000.00
# 6       Heba    Ismail   50000.00
# 7      Laila     Ahmed   20000.00
# 8     Joseph    Patton    2629.13
# 9       Noah     Moran    8626.96

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x[0:2]
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0     5000.0
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K    10000.0
#
#    Years with Bank
# 0                5
# 1                6

# %%
x[:3]
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller     azikez@gahew.mr     S1T 4E6    9072.02
#
#    Years with Bank
# 0                5
# 1                6
# 2                7

# %%
x[0:6:2]
# Out:
#   First Name Last Name             Email Postal Code  Net Worth  \
# 0      Bird      Steve    bird@gmail.com     N94 3M0    5000.00
# 2       Nina    Keller   azikez@gahew.mr     S1T 4E6    9072.02
# 4       Kate      Noor  kate@hotmail.com     K8N 5H6    5000.00
#
#    Years with Bank
# 0                5
# 2                7
# 4               22

# %% [markdown]
# # MINI CHALLENGE #5:
#
# # Select the following columns from the dataFrame Net Worth, Years with Bank, and Postal Code

# %%
x=pd.read_csv('Downloads\\bank_client_information.csv')
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x[["Net Worth","Years with Bank","Postal Code"]]
# Out:
#    Net Worth  Years with Bank Postal Code
# 0    5000.00                5     N94 3M0
# 1   10000.00                6     N8S 14K
# 2    9072.02                7     S1T 4E6
# 3   11072.02               10     N7T 3E6
# 4    5000.00               22     K8N 5H6
# 5  100000.00               26     J7H 3HY
# 6   50000.00               11     K8Y 3M8
# 7   20000.00                3     J8Y 3M0
# 8    2629.13                1     M6U 5U7
# 9    8626.96               13     K2D 4M9

# %%
x[4:6]
# Out:
#   First Name Last Name             Email Postal Code  Net Worth  \
# 4       Kate      Noor  kate@hotmail.com     K8N 5H6     5000.0
# 5      Samer        Mo   samer@gmail.com     J7H 3HY   100000.0
#
#    Years with Bank
# 4               22
# 5               26

# %% [markdown]
# # 6. ADDING/DELETING COLUMNS TO DATAFRAME

# %%
x=pd.read_csv('Downloads\\bank_client_information.csv')
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x["Age"]=[23,34,46,565,5,6,676,787,78,45]

# %%
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Age
# 0                5   23
# 1                6   34
# 2                7   46
# 3               10  565
# 4               22    5
# 5               26    6
# ...

# %%
x["age"]=x["Years with Bank"]*10

# %%
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Age  age
# 0                5   23   50
# 1                6   34   60
# 2                7   46   70
# 3               10  565  100
# 4               22    5  220
# ...

# %%
x["Total"]=x["age"]*x["Age"]

# %%
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Age  age  Total
# 0                5   23   50   1150
# 1                6   34   60   2040
# 2                7   46   70   3220
# 3               10  565  100  56500
# ...

# %%
x.insert(2,column="YEAH Boyyy",value=x["Total"]*x["Age"])

# %%
x
# Out:
#   First Name Last Name  YEAH Boyyy                    Email Postal Code  \
# 0      Bird      Steve       26450           bird@gmail.com     N94 3M0
# 1       Noah     Small       69360       nsmall@hotmail.com     N8S 14K
# 2       Nina    Keller      148120          azikez@gahew.mr     S1T 4E6
# 3    Chanel      Steve    31922500         chanel@gmail.com     N7T 3E6
# 4       Kate      Noor        5500         kate@hotmail.com     K8N 5H6
# 5      Samer        Mo        9360          samer@gmail.com     J7H 3HY
# 6       Heba    Ismail    50267360  heba.ismail@hotmail.com     K8Y 3M8
# 7      Laila     Ahmed    18581070      Laila.a@hotmail.com     J8Y 3M0
# 8     Joseph    Patton       60840           daafeja@boh.jm     M6U 5U7
# 9       Noah     Moran      263250        guutodi@bigwoc.kw     K2D 4M9
#
#    Net Worth  Years with Bank  Age  age  Total
# 0    5000.00                5   23   50   1150
# 1   10000.00                6   34   60   2040
# ...

# %%
del x["Email"]

# %%
x
# Out:
#   First Name Last Name  YEAH Boyyy Postal Code  Net Worth  Years with Bank  \
# 0      Bird      Steve       26450     N94 3M0    5000.00                5
# 1       Noah     Small       69360     N8S 14K   10000.00                6
# 2       Nina    Keller      148120     S1T 4E6    9072.02                7
# 3    Chanel      Steve    31922500     N7T 3E6   11072.02               10
# 4       Kate      Noor        5500     K8N 5H6    5000.00               22
# 5      Samer        Mo        9360     J7H 3HY  100000.00               26
# 6       Heba    Ismail    50267360     K8Y 3M8   50000.00               11
# 7      Laila     Ahmed    18581070     J8Y 3M0   20000.00                3
# 8     Joseph    Patton       60840     M6U 5U7    2629.13                1
# 9       Noah     Moran      263250     K2D 4M9    8626.96               13
#
#    Age  age  Total
# 0   23   50   1150
# 1   34   60   2040
# 2   46   70   3220
# 3  565  100  56500
# 4    5  220   1100
# 5    6  260   1560
# ...

# %%
x.drop(labels=["Last Name"],axis=1 ,inplace=True)

# %%
x
# Out:
#   First Name  YEAH Boyyy Postal Code  Net Worth  Years with Bank  Age  age  \
# 0      Bird        26450     N94 3M0    5000.00                5   23   50
# 1       Noah       69360     N8S 14K   10000.00                6   34   60
# 2       Nina      148120     S1T 4E6    9072.02                7   46   70
# 3    Chanel     31922500     N7T 3E6   11072.02               10  565  100
# 4       Kate        5500     K8N 5H6    5000.00               22    5  220
# 5      Samer        9360     J7H 3HY  100000.00               26    6  260
# 6       Heba    50267360     K8Y 3M8   50000.00               11  676  110
# 7      Laila    18581070     J8Y 3M0   20000.00                3  787   30
# 8     Joseph       60840     M6U 5U7    2629.13                1   78   10
# 9       Noah      263250     K2D 4M9    8626.96               13   45  130
#
#    Total
# 0   1150
# 1   2040
# 2   3220
# 3  56500
# 4   1100
# 5   1560
# 6  74360
# 7  23610
# 8    780
# 9   5850

# %%
x.drop(labels=["Age","age","Total"],axis=1,inplace=True)

# %%
x
# Out:
#   First Name  YEAH Boyyy Postal Code  Net Worth  Years with Bank
# 0      Bird        26450     N94 3M0    5000.00                5
# 1       Noah       69360     N8S 14K   10000.00                6
# 2       Nina      148120     S1T 4E6    9072.02                7
# 3    Chanel     31922500     N7T 3E6   11072.02               10
# 4       Kate        5500     K8N 5H6    5000.00               22
# 5      Samer        9360     J7H 3HY  100000.00               26
# 6       Heba    50267360     K8Y 3M8   50000.00               11
# 7      Laila    18581070     J8Y 3M0   20000.00                3
# 8     Joseph       60840     M6U 5U7    2629.13                1
# 9       Noah      263250     K2D 4M9    8626.96               13

# %%
x.drop(labels=[3],axis=0,inplace=True)

# %%
x
# Out:
#   First Name  YEAH Boyyy Postal Code  Net Worth  Years with Bank
# 0      Bird        26450     N94 3M0    5000.00                5
# 1       Noah       69360     N8S 14K   10000.00                6
# 2       Nina      148120     S1T 4E6    9072.02                7
# 4       Kate        5500     K8N 5H6    5000.00               22
# 5      Samer        9360     J7H 3HY  100000.00               26
# 6       Heba    50267360     K8Y 3M8   50000.00               11
# 7      Laila    18581070     J8Y 3M0   20000.00                3
# 8     Joseph       60840     M6U 5U7    2629.13                1
# 9       Noah      263250     K2D 4M9    8626.96               13

# %%
x.drop(labels=[0,2],axis=0,inplace=True)

# %%
x
# Out:
#   First Name  YEAH Boyyy Postal Code  Net Worth  Years with Bank
# 1       Noah       69360     N8S 14K   10000.00                6
# 4       Kate        5500     K8N 5H6    5000.00               22
# 5      Samer        9360     J7H 3HY  100000.00               26
# 6       Heba    50267360     K8Y 3M8   50000.00               11
# 7      Laila    18581070     J8Y 3M0   20000.00                3
# 8     Joseph       60840     M6U 5U7    2629.13                1
# 9       Noah      263250     K2D 4M9    8626.96               13

# %%
x.drop(labels=[6,7,8,9],axis=0,inplace=True)

# %%
x
# Out:
#   First Name  YEAH Boyyy Postal Code  Net Worth  Years with Bank
# 1       Noah       69360     N8S 14K    10000.0                6
# 4       Kate        5500     K8N 5H6     5000.0               22
# 5      Samer        9360     J7H 3HY   100000.0               26

# %%
x=pd.read_csv('Downloads\\bank_client_information.csv')
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x.drop(labels=[i for i in range(5,10)])
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller     azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve    chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor    kate@hotmail.com     K8N 5H6    5000.00
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22

# %%
x.drop(labels=(x.iloc[6:]),axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 x.drop(labels=(x.iloc[6:]),axis=0)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
# ...

# %%
x.drop(labels= [i for i in range(6,10)])
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller     azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve    chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor    kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo     samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
