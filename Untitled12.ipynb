# %%
import pandas as pd

# %%
x=pd.read_csv("Downloads\\bollywood.csv")

# %%
x
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
x.loc['2 States':'Bobby Jasoos']
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 20     21     1-Feb-13                        David           N  Thriller
# 21     22     7-Mar-14                  Gulaab Gang           N    Action
# 22     23    14-Feb-14                       Gunday           N     Action
# 23     24     2-Oct-14                       Haider          FS     Drama
# 24     25    21-Nov-14                 Happy Ending           N    Romance
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
x.iloc[0:4]
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2     4-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama        7
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
# loc ,iloc 
x.set_index('MovieName',inplace=True)

# %%
x
# Out:
#                              SlNo Release Date ReleaseTime      Genre  Budget  \
# MovieName
# 2 States                        1    18-Apr-14          LW    Romance      36
# Table No. 21                    2     4-Jan-13           N  Thriller       10
# Amit Sahni Ki List              3    18-Jul-14           N     Comedy      10
# Rajdhani Express                4     4-Jan-13           N     Drama        7
# Bobby Jasoos                    5     4-Jul-14           N     Comedy      18
# ...                           ...          ...         ...        ...     ...
# Dum Laga Ke Haisha            145    27-Feb-15           N     Comedy      15
# NH10                          146    13-Mar-15           N   Thriller      13
# Dilliwali Zaalim Girlfriend   147    20-Mar-15           N     Comedy      32
# Hunterrr                      148    20-Mar-15           N     Comedy       5
# Kochadaiiyaan                 149    23-May-14          HS     Action     150
#
# ...

# %%
x.loc['2 States':'Bobby Jasoos']
# Out:
#                     SlNo Release Date ReleaseTime      Genre  Budget  \
# MovieName
# 2 States               1    18-Apr-14          LW    Romance      36
# Table No. 21           2     4-Jan-13           N  Thriller       10
# Amit Sahni Ki List     3    18-Jul-14           N     Comedy      10
# Rajdhani Express       4     4-Jan-13           N     Drama        7
# Bobby Jasoos           5     4-Jul-14           N     Comedy      18
#
#                     BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# MovieName
# 2 States                         104.00       8576361         26622
# Table No. 21                      12.00       1087320          1129
# Amit Sahni Ki List                 4.00        572336           586
# Rajdhani Express                   0.35         42626            86
# Bobby Jasoos                      10.80       3113427          4512
#
#                     YoutubeDislikes
# MovieName
# 2 States                       2527
# ...

# %%
x.iloc[0:4]
# Out:
#                     SlNo Release Date ReleaseTime      Genre  Budget  \
# MovieName
# 2 States               1    18-Apr-14          LW    Romance      36
# Table No. 21           2     4-Jan-13           N  Thriller       10
# Amit Sahni Ki List     3    18-Jul-14           N     Comedy      10
# Rajdhani Express       4     4-Jan-13           N     Drama        7
#
#                     BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# MovieName
# 2 States                         104.00       8576361         26622
# Table No. 21                      12.00       1087320          1129
# Amit Sahni Ki List                 4.00        572336           586
# Rajdhani Express                   0.35         42626            86
#
#                     YoutubeDislikes
# MovieName
# 2 States                       2527
# Table No. 21                    137
# Amit Sahni Ki List               54
# Rajdhani Express                 19

# %%
#loc it work on string i.e on names


ffill
bfill

x.fillna(method='ffill',axis=1,inplace=True)
x.fillna(method='bfill',axis=1,inplace=True)




#null values check 
#fill ffill,bfill
#null values remove
#Groupby
#concat
#metadata
#loc
#iloc
#delete
#insert
#multiple columns
