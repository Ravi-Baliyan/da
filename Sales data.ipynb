# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=pd.read_csv("C:\\Users\\baliy\\Downloads\\First_Quote.csv")

# %%
x
# Out:
#               Zone                                       Site Address  \
# 0        Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1        Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2        Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 3        Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4        Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...            ...                                                ...
# 5164  Not assigned  Opp Polytechnic, Kosamba Road, Bhagdawada / Va...
# 5165  Not assigned  Samrat House, Opp Meera Society 2nd gate, Shan...
# 5166  Not assigned  alwarthirunagar, gandhi road, valasaravakkam /...
# 5167  Not assigned                                 karnal 132001 / IN
# 5168  Not assigned      naomi konambai, edappally / Kochi 682024 / IN
#
#               Region  Opportunity ID Opp Created On Enquiry Created By  \
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5169 entries, 0 to 5168
# Data columns (total 63 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Zone                              5169 non-null   object
#  1   Site Address                      5169 non-null   object
#  2   Region                            5169 non-null   object
#  3   Opportunity ID                    5169 non-null   int64
#  4   Opp Created On                    5169 non-null   object
#  5   Enquiry Created By                5169 non-null   object
#  6   Customer Name                     5169 non-null   object
#  7   Contact Number                    5169 non-null   object
#  8   E-Mail                            5169 non-null   object
#  9   City                              5169 non-null   object
#  10  State                             5169 non-null   object
# ...

# %%
x.isnull().sum()
# Out:
# Zone                     0
# Site Address             0
# Region                   0
# Opportunity ID           0
# Opp Created On           0
#                         ..
# Closed Customer value    0
# Closed Basic value       0
# MSC Material value       0
# MSC Gross Value          0
# Lost Price               0
# Length: 63, dtype: int64

# %%
b=pd.read_csv("C:\\Users\\baliy\\Downloads\\Opp_Created.csv")

# %%
b
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  # 209-99 1st Main Rd, NGEF Layout, Krishnaiyya...
# 1         Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 2         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 3         Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 4         Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# ...             ...                                                ...
# 10916  Not assigned                       ring road / Rewa 486001 / IN
# 10917  Not assigned                    roopengarh, / ajmer 305814 / IN
# 10918  Not assigned                sanjay nagar / Bareilly 243005 / IN
# 10919  Not assigned                                        shekta / IN
# 10920  Not assigned  village post gaighat dist ballia / Ballia 2772...
#
#                Region  Opportunity ID Opp Created On  Enquiry Created By  \
# ...

# %%
b.isnull().sum()
# Out:
# Zone                     0
# Site Address             0
# Region                   0
# Opportunity ID           0
# Opp Created On           0
#                         ..
# Closed Customer value    0
# Closed Basic value       0
# MSC Material value       0
# MSC Gross Value          0
# Lost Price               0
# Length: 63, dtype: int64

# %%
c=pd.read_csv("C:\\Users\\baliy\\Downloads\\Close_Date.csv")

# %%
c
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  "Channabasava", 1st cross, near Mission compou...
# 1         Bangalore  # 108-F9, 6th cross, 2nd main, HGH layout / Ba...
# 2         Bangalore  # 3A Fair Field Appt,Benson Town / Banglore 56...
# 3         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 4         Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...             ...                                                ...
# 10147  Not assigned     Village Hyatpur Rurki / Navashehar 144532 / IN
# 10148  Not assigned  Vipanchika house ,SN Junction / Trippunithura ...
# 10149  Not assigned               collecterate road / Rewa 486001 / IN
# 10150  Not assigned                                 karnal 132001 / IN
# 10151  Not assigned                                  satna 485001 / IN
#
#                Region  Opportunity ID Opp Created On Enquiry Created By  \
# ...

# %%
c.isnull().sum()
# Out:
# Zone                     0
# Site Address             0
# Region                   0
# Opportunity ID           0
# Opp Created On           0
#                         ..
# Closed Customer value    0
# Closed Basic value       0
# MSC Material value       0
# MSC Gross Value          0
# Lost Price               0
# Length: 63, dtype: int64

# %%
d=pd.concat([x,b,c])

# %%
d
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2         Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 3         Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4         Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...             ...                                                ...
# 10147  Not assigned     Village Hyatpur Rurki / Navashehar 144532 / IN
# 10148  Not assigned  Vipanchika house ,SN Junction / Trippunithura ...
# 10149  Not assigned               collecterate road / Rewa 486001 / IN
# 10150  Not assigned                                 karnal 132001 / IN
# 10151  Not assigned                                  satna 485001 / IN
#
#                Region  Opportunity ID Opp Created On Enquiry Created By  \
# ...

# %%
for i in x['Region']:
    print(i)
# Out:
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# UPC BLR 2
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# UPC BLR 2
# Bangalore City
# UPC BLR 2
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# UPC BLR 2
# UPC BLR 2
# UPC BLR 2
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# Bangalore City
# ...

# %%
s=d.isna().sum()
s1=d.columns
for i,j in zip(s,s1):
    print(i,j)
# Out:
# 0 Zone
# 0 Site Address
# 0 Region
# 0 Opportunity ID
# 0 Opp Created On
# 0 Enquiry Created By
# 0 Customer Name
# 0 Contact Number
# 0 E-Mail
# 0 City
# 0 State
# 0 Pincode
# 0 Source of Enq
# 0 Sales Owner
# 0 Sales Owner ID
# 0 CSE Name
# 0 Nature of Work
# 0 Influencer Involved
# 0 Influencer Name
# 0 First Interaction Date
# 0 Site Visit Date
# 0 Persuasion Date
# 0 Showroom Visit Date
# 0 Boq Received Date
# 0 Product Category
# 0 Client expectation Price Bracket
# 0 Quote Segment
# 0 WM Order Type
# 0 WM Quote ID
# 0 First Quote Date
# 0 Latest Quote Date
# 0 Quote Review Date
# 0 Expected Closure Month
# 0 No. of Sales Quote
# 0 Won/Lost/In Process
# 0 Last Progression Stage
# 0 Order in Hand
# 0 Order in Hand Date
# 0 Status-Hot / Warm/ Cold
# 17 Remarks
# 0 Main Competitor
# 0 Reason for Status
# 0 Expected Site Readiness Date
# 0 1st Discount Given Date
# 0 2nd Discount Given Date
# 0 Order Basis to Fenesta
# 0 Quote Area
# 14 Next Step
# 0 Next Step Due Date
# ...

# %%
d
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2         Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 3         Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4         Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...             ...                                                ...
# 10147  Not assigned     Village Hyatpur Rurki / Navashehar 144532 / IN
# 10148  Not assigned  Vipanchika house ,SN Junction / Trippunithura ...
# 10149  Not assigned               collecterate road / Rewa 486001 / IN
# 10150  Not assigned                                 karnal 132001 / IN
# 10151  Not assigned                                  satna 485001 / IN
#
#                Region  Opportunity ID Opp Created On Enquiry Created By  \
# ...

# %%
d.drop(['Next Step','Remarks'],axis=1,inplace=True)

# %%
d
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2         Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 3         Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4         Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...             ...                                                ...
# 10147  Not assigned     Village Hyatpur Rurki / Navashehar 144532 / IN
# 10148  Not assigned  Vipanchika house ,SN Junction / Trippunithura ...
# 10149  Not assigned               collecterate road / Rewa 486001 / IN
# 10150  Not assigned                                 karnal 132001 / IN
# 10151  Not assigned                                  satna 485001 / IN
#
#                Region  Opportunity ID Opp Created On Enquiry Created By  \
# ...

# %%
data=pd.read_excel("C:\\Users\\baliy\\Downloads\\exp1.xlsx",sheet_name='Sheet1')

# %%
data
# Out:
#             ID                                            Subject     Status  \
# 0      1592287                         Shapoorji Pallonji Company  Completed
# 1      1583328          subhajit- SubVisit-Customer First Meeting  Completed
# 2      1592480                                      MANDEEP SINGH  Completed
# 3      1585432                                           subhajit  Completed
# 4      1585424          subhajit- SubVisit-Customer First Meeting  Completed
# ...        ...                                                ...        ...
# 45976  1575632                     Akash Sawant design discussion  Completed
# 45977  1575537  Akash Sawant design discussion- SubVisit-Custo...  Completed
# 45978  1586910                       Dipti Pore design discussion  Completed
# 45979  1586849  Dipti Pore design discussion- SubVisit-Quote R...  Completed
# 45980  1594955                                 TBC dealer meeting       Open
#
#                           Account  \
# ...

# %%
data1=pd.read_csv("C:\\Users\\baliy\\Downloads\\exxpppppp1.csv")
# Out:
# C:\Users\baliy\AppData\Local\Temp\ipykernel_10280\8630769.py:1: DtypeWarning: Columns (11,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1=pd.read_csv("C:\\Users\\baliy\\Downloads\\exxpppppp1.csv")

# %%
data1
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2         Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 3         Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4         Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...             ...                                                ...
# 26237  Not assigned     Village Hyatpur Rurki / Navashehar 144532 / IN
# 26238  Not assigned  Vipanchika house ,SN Junction / Trippunithura ...
# 26239  Not assigned               collecterate road / Rewa 486001 / IN
# 26240  Not assigned                                 karnal 132001 / IN
# 26241  Not assigned                                  satna 485001 / IN
#
#                Region  Opportunity ID Opp Created On Enquiry Created By  \
# ...

# %%
for i in data1['Region']:
    for j in data1.index:
            print(data[i][j])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
#       1 for i in data1['Region']:
#       2     for j in data1.index:
# ----> 3             print(data[i][j])
#
# NameError: name 'data' is not defined

# %%
data1

# %%
df=data1.replace(['#'],np.nan)

# %%
df

# %%
df.info()

# %%
df.fillna(method='ffill',inplace=True)

# %%
df

# %%
data

# %%
data.info()

# %%
data.fillna(method='ffill',inplace=True)

# %%
data
# Out:
#             ID                                            Subject     Status  \
# 0      1592287                         Shapoorji Pallonji Company  Completed
# 1      1583328          subhajit- SubVisit-Customer First Meeting  Completed
# 2      1592480                                      MANDEEP SINGH  Completed
# 3      1585432                                           subhajit  Completed
# 4      1585424          subhajit- SubVisit-Customer First Meeting  Completed
# ...        ...                                                ...        ...
# 45976  1575632                     Akash Sawant design discussion  Completed
# 45977  1575537  Akash Sawant design discussion- SubVisit-Custo...  Completed
# 45978  1586910                       Dipti Pore design discussion  Completed
# 45979  1586849  Dipti Pore design discussion- SubVisit-Quote R...  Completed
# 45980  1594955                                 TBC dealer meeting       Open
#
#                           Account  \
# ...

# %%
data.to_csv("Table1.csv")

# %%
data.fillna(method='bfill',inplace=True)

# %%
for i in data.isna().sum():
    print(i)

# %% [markdown]
# # What’s holding you back from reaching your revenue (or profit, or other) goals?
# # What goals and objectives do you have in general for your business? For this particular area?

# %%
l=[1,2,3,4,5]
l1=[2,3,4,5]
print(list(zip(l,l1)))
# Out:
# [(1, 2), (2, 3), (3, 4), (4, 5)]

# %%
x='action '
x[0:6]
# Out:
# 'action'

# %%
#groupby
#concat
#merge
#set index
# reset index
#iloc
#loc
#filtering
#ffill
#bfill
#null 
#colum ke null 
# datatypes 
#rows ki nulls
#metadata

# %%
x={'date':['10/feb/2021','9/jan/2021','5/apr/2021']}

# %%
d=pd.DataFrame(x)

# %%
d
# Out:
#           date
# 0  10/feb/2021
# 1   9/jan/2021
# 2   5/apr/2021

# %%
d=[]
for i in d['date']:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 d=[]
# ----> 2 for i in d['date']:
#       3     print(i)
#
# TypeError: list indices must be integers or slices, not str

# %%
d['Month']=a

# %%
a
# Out:
# 'apr'

# %% [markdown]
# #

# %%
d
# Out:
#           date Month
# 0  10/feb/2021   apr
# 1   9/jan/2021   apr
# 2   5/apr/2021   apr

# %%
l=[1,2,3,4,2,1,1,1,1,5,6,6]
while True:
    a=0
    if l==1:
        a=a+
        l.insert(l[a+1],0)
        a=a-1
    else:
        a=a-1
print(l)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       6         a=a-1
#       7     else:
# ----> 8         a=a-1
#       9 print(l)
#
# KeyboardInterrupt:

# %%
l=[1,2,3,4,2,1,1,1,1,5,6,6]
for i in l:
    if i==1:
        l.insert(i+1,0)
print(l)
