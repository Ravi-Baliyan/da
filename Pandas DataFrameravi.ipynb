# %%
import pandas as pd

a=pd.DataFrame({'Bank client ID':[111,222,333,444],
               'Bank Client Nmae':['Laila Aly','Kate Steve','Nicole Mitch',"Francis"],
               'Net Worth [$]':[35000,3000,100000,2000],
                'Years with bank':[4,7,1,15]})
a
# Out:
#    Bank client ID Bank Client Nmae  Net Worth [$]  Years with bank
# 0             111        Laila Aly          35000                4
# 1             222       Kate Steve           3000                7
# 2             333     Nicole Mitch         100000                1
# 3             444          Francis           2000               15

# %%
dict(a)
# Out:
# {'Bank client ID': 0    111
#  1    222
#  2    333
#  3    444
#  Name: Bank client ID, dtype: int64,
#  'Bank Client Nmae': 0       Laila Aly
#  1      Kate Steve
#  2    Nicole Mitch
#  3         Francis
#  Name: Bank Client Nmae, dtype: object,
#  'Net Worth [$]': 0     35000
#  1      3000
#  2    100000
#  3      2000
#  Name: Net Worth [$], dtype: int64,
#  'Years with bank': 0     4
#  1     7
#  2     1
#  3    15
#  Name: Years with bank, dtype: int64}

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.head(2)
# Out:
#    Bank client ID Bank Client Nmae  Net Worth [$]  Years with bank
# 0             111        Laila Aly          35000                4
# 1             222       Kate Steve           3000                7

# %%
a.tail(3)
# Out:
#    Bank client ID Bank Client Nmae  Net Worth [$]  Years with bank
# 1             222       Kate Steve           3000                7
# 2             333     Nicole Mitch         100000                1
# 3             444          Francis           2000               15

# %%
a.shape
# Out:
# (4, 4)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Bank client ID    4 non-null      int64
#  1   Bank Client Nmae  4 non-null      object
#  2   Net Worth [$]     4 non-null      int64
#  3   Years with bank   4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 256.0+ bytes

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First Name       10 non-null     object
#  1   Last Name        10 non-null     object
#  2   Email            10 non-null     object
#  3   Postal Code      10 non-null     object
#  4   Net Worth        10 non-null     float64
#  5   Years with Bank  10 non-null     int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 608.0+ bytes

# %%
d.isna().sum()
# Out:
# First Name         0
# Last Name          0
# Email              0
# Postal Code        0
# Net Worth          0
# Years with Bank    0
# dtype: int64

# %%
d.fillna(method='ffill',inplace=True)

# %%
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x=d.loc[5:8]

# %%
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
#
#    Years with Bank
# 5               26
# 6               11
# 7                3
# 8                1

# %%
d.set_index('First Name',inplace=True)

# %%
d
# Out:
#            Last Name                    Email Postal Code  Net Worth  \
# First Name
# Bird           Steve           bird@gmail.com     N94 3M0    5000.00
# Noah           Small       nsmall@hotmail.com     N8S 14K   10000.00
# Nina          Keller          azikez@gahew.mr     S1T 4E6    9072.02
# Chanel         Steve         chanel@gmail.com     N7T 3E6   11072.02
# Kate            Noor         kate@hotmail.com     K8N 5H6    5000.00
# Samer             Mo          samer@gmail.com     J7H 3HY  100000.00
# Heba          Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Laila          Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Joseph        Patton           daafeja@boh.jm     M6U 5U7    2629.13
# Noah           Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#             Years with Bank
# First Name
# Bird                      5
# Noah                      6
# Nina                      7
# Chanel                   10
# Kate                     22
# ...

# %%
d.reset_index('First Name',inplace=True)

# %%
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
a=[d['Postal Code'][0:4]]

# %%
a
# Out:
# [0    N94 3M0
#  1    N8S 14K
#  2    S1T 4E6
#  3    N7T 3E6
#  Name: Postal Code, dtype: object]

# %%
for i in d['Net Worth']:
    a=int(i)
    #print(a)
    if a>20000:
        print(a)
else:
    print('jda')
# Out:
# 100000
# 50000
# jda

# %%
x =d[d['Net Worth']>20000]

# %%
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY   100000.0
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8    50000.0
#
#    Years with Bank
# 5               26
# 6               11

# %%
x=pd.read_html('https://www.livingin-canada.com/house-prices-canada.html')
x
# Out:
# [                                                City  \
#  0                                      Vancouver, BC
#  1                                       Toronto, Ont
#  2                                        Ottawa, Ont
#  3                                       Calgary, Alb
#  4                                      Montreal, Que
#  5                                        Halifax, NS
#  6                                       Regina, Sask
#  7                                    Fredericton, NB
#  8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
#  0                                         $1,036,000
#  1                                           $870,000
#  2                                           $479,000
#  3                                           $410,000
#  4                                           $435,000
#  5                                           $331,000
# ...

# %%
x[0]
# Out:
#                                                 City  \
# 0                                      Vancouver, BC
# 1                                       Toronto, Ont
# 2                                        Ottawa, Ont
# 3                                       Calgary, Alb
# 4                                      Montreal, Que
# 5                                        Halifax, NS
# 6                                       Regina, Sask
# 7                                    Fredericton, NB
# 8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                  Average House Price  \
# 0                                         $1,036,000
# 1                                           $870,000
# 2                                           $479,000
# 3                                           $410,000
# 4                                           $435,000
# 5                                           $331,000
# 6                                           $254,000
# ...

# %%
x[1]
# Out:
#                                              Province  \
# 0                                    British Columbia
# 1                                             Ontario
# 2                                             Alberta
# 3                                              Quebec
# 4                                            Manitoba
# 5                                        Saskatchewan
# 6                                         Nova Scotia
# 7                                Prince Edward Island
# 8                             Newfoundland / Labrador
# 9                                       New Brunswick
# 10                                   Canadian Average
# 11  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
# 0                                            $736,000
# 1                                            $594,000
# 2                                            $353,000
# ...

# %%
d.to_csv('Bank client',index=True)
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d.set_index("Email",inplace=True)

# %%
d
# Out:
#                         First Name Last Name Postal Code  Net Worth  \
# Email
# bird@gmail.com               Bird      Steve     N94 3M0    5000.00
# nsmall@hotmail.com            Noah     Small     N8S 14K   10000.00
# azikez@gahew.mr               Nina    Keller     S1T 4E6    9072.02
# chanel@gmail.com           Chanel      Steve     N7T 3E6   11072.02
# kate@hotmail.com              Kate      Noor     K8N 5H6    5000.00
# samer@gmail.com              Samer        Mo     J7H 3HY  100000.00
# heba.ismail@hotmail.com       Heba    Ismail     K8Y 3M8   50000.00
# Laila.a@hotmail.com          Laila     Ahmed     J8Y 3M0   20000.00
# daafeja@boh.jm              Joseph    Patton     M6U 5U7    2629.13
# guutodi@bigwoc.kw             Noah     Moran     K2D 4M9    8626.96
#
#                          Years with Bank
# Email
# bird@gmail.com                         5
# nsmall@hotmail.com                     6
# azikez@gahew.mr                        7
# ...

# %%
d.reset_index(inplace=True)
d
# Out:
#                      Email First Name Last Name Postal Code  Net Worth  \
# 0           bird@gmail.com      Bird      Steve     N94 3M0    5000.00
# 1       nsmall@hotmail.com       Noah     Small     N8S 14K   10000.00
# 2          azikez@gahew.mr       Nina    Keller     S1T 4E6    9072.02
# 3         chanel@gmail.com    Chanel      Steve     N7T 3E6   11072.02
# 4         kate@hotmail.com       Kate      Noor     K8N 5H6    5000.00
# 5          samer@gmail.com      Samer        Mo     J7H 3HY  100000.00
# 6  heba.ismail@hotmail.com       Heba    Ismail     K8Y 3M8   50000.00
# 7      Laila.a@hotmail.com      Laila     Ahmed     J8Y 3M0   20000.00
# 8           daafeja@boh.jm     Joseph    Patton     M6U 5U7    2629.13
# 9        guutodi@bigwoc.kw       Noah     Moran     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv',index_col="Email")
d
# Out:
#                         First Name Last Name Postal Code  Net Worth  \
# Email
# bird@gmail.com               Bird      Steve     N94 3M0    5000.00
# nsmall@hotmail.com            Noah     Small     N8S 14K   10000.00
# azikez@gahew.mr               Nina    Keller     S1T 4E6    9072.02
# chanel@gmail.com           Chanel      Steve     N7T 3E6   11072.02
# kate@hotmail.com              Kate      Noor     K8N 5H6    5000.00
# samer@gmail.com              Samer        Mo     J7H 3HY  100000.00
# heba.ismail@hotmail.com       Heba    Ismail     K8Y 3M8   50000.00
# Laila.a@hotmail.com          Laila     Ahmed     J8Y 3M0   20000.00
# daafeja@boh.jm              Joseph    Patton     M6U 5U7    2629.13
# guutodi@bigwoc.kw             Noah     Moran     K2D 4M9    8626.96
#
#                          Years with Bank
# Email
# bird@gmail.com                         5
# nsmall@hotmail.com                     6
# azikez@gahew.mr                        7
# ...

# %%
a=d.reset_index()
a
# Out:
#                      Email First Name Last Name Postal Code  Net Worth  \
# 0           bird@gmail.com      Bird      Steve     N94 3M0    5000.00
# 1       nsmall@hotmail.com       Noah     Small     N8S 14K   10000.00
# 2          azikez@gahew.mr       Nina    Keller     S1T 4E6    9072.02
# 3         chanel@gmail.com    Chanel      Steve     N7T 3E6   11072.02
# 4         kate@hotmail.com       Kate      Noor     K8N 5H6    5000.00
# 5          samer@gmail.com      Samer        Mo     J7H 3HY  100000.00
# 6  heba.ismail@hotmail.com       Heba    Ismail     K8Y 3M8   50000.00
# 7      Laila.a@hotmail.com      Laila     Ahmed     J8Y 3M0   20000.00
# 8           daafeja@boh.jm     Joseph    Patton     M6U 5U7    2629.13
# 9        guutodi@bigwoc.kw       Noah     Moran     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
s=a[["Email",'Net Worth']]
s
# Out:
#                      Email  Net Worth
# 0           bird@gmail.com    5000.00
# 1       nsmall@hotmail.com   10000.00
# 2          azikez@gahew.mr    9072.02
# 3         chanel@gmail.com   11072.02
# 4         kate@hotmail.com    5000.00
# 5          samer@gmail.com  100000.00
# 6  heba.ismail@hotmail.com   50000.00
# 7      Laila.a@hotmail.com   20000.00
# 8           daafeja@boh.jm    2629.13
# 9        guutodi@bigwoc.kw    8626.96

# %%
# 6.

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d['Age']=[12,12,3,4,45,67,89,76,54,33]
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Age
# 0                5   12
# 1                6   12
# 2                7    3
# 3               10    4
# 4               22   45
# 5               26   67
# ...

# %%
d.insert(0,column='Credit Score',value=[23,33,543,65,564,56,65,75,43,435])

# %%
d
# Out:
#    Credit Score First Name Last Name                    Email Postal Code  \
# 0            23      Bird      Steve           bird@gmail.com     N94 3M0
# 1            33       Noah     Small       nsmall@hotmail.com     N8S 14K
# 2           543       Nina    Keller          azikez@gahew.mr     S1T 4E6
# 3            65    Chanel      Steve         chanel@gmail.com     N7T 3E6
# 4           564       Kate      Noor         kate@hotmail.com     K8N 5H6
# 5            56      Samer        Mo          samer@gmail.com     J7H 3HY
# 6            65       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8
# 7            75      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0
# 8            43     Joseph    Patton           daafeja@boh.jm     M6U 5U7
# 9           435       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9
#
#    Net Worth  Years with Bank  Age
# 0    5000.00                5   12
# 1   10000.00                6   12
# 2    9072.02                7    3
# ...

# %%
del d['Email']
d
# Out:
#    Credit Score First Name Last Name Postal Code  Net Worth  Years with Bank  \
# 0            23      Bird      Steve     N94 3M0    5000.00                5
# 1            33       Noah     Small     N8S 14K   10000.00                6
# 2           543       Nina    Keller     S1T 4E6    9072.02                7
# 3            65    Chanel      Steve     N7T 3E6   11072.02               10
# 4           564       Kate      Noor     K8N 5H6    5000.00               22
# 5            56      Samer        Mo     J7H 3HY  100000.00               26
# 6            65       Heba    Ismail     K8Y 3M8   50000.00               11
# 7            75      Laila     Ahmed     J8Y 3M0   20000.00                3
# 8            43     Joseph    Patton     M6U 5U7    2629.13                1
# 9           435       Noah     Moran     K2D 4M9    8626.96               13
#
#    Age
# 0   12
# 1   12
# 2    3
# 3    4
# 4   45
# 5   67
# 6   89
# 7   76
# 8   54
# 9   33

# %%
d.drop(labels=["Last Name"],axis=1,inplace=True)
d
# Out:
#    Credit Score First Name Postal Code  Net Worth  Years with Bank  Age
# 0            23      Bird      N94 3M0    5000.00                5   12
# 1            33       Noah     N8S 14K   10000.00                6   12
# 2           543       Nina     S1T 4E6    9072.02                7    3
# 3            65    Chanel      N7T 3E6   11072.02               10    4
# 4           564       Kate     K8N 5H6    5000.00               22   45
# 5            56      Samer     J7H 3HY  100000.00               26   67
# 6            65       Heba     K8Y 3M8   50000.00               11   89
# 7            75      Laila     J8Y 3M0   20000.00                3   76
# 8            43     Joseph     M6U 5U7    2629.13                1   54
# 9           435       Noah     K2D 4M9    8626.96               13   33

# %%
x=d.pop("Age")

# %%
x
# Out:
# 0    12
# 1    12
# 2     3
# 3     4
# 4    45
# 5    67
# 6    89
# 7    76
# 8    54
# 9    33
# Name: Age, dtype: int64

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv',index_col='Last Name')
d
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#            Years with Bank
# Last Name
# Steve                    5
# Small                    6
# Keller                   7
# Steve                   10
# Noor                    22
# ...

# %%
d.sort_index(inplace=True)

# %%
d
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Ismail                  11
# Keller                   7
# Mo                      26
# Moran                   13
# ...

# %%
d.loc['Small']
# Out:
# First Name                       Noah
# Email              nsmall@hotmail.com
# Postal Code                   N8S 14K
# Net Worth                     10000.0
# Years with Bank                     6
# Name: Small, dtype: object

# %%
d.loc['Steve']
# Out:
#           First Name             Email Postal Code  Net Worth  Years with Bank
# Last Name
# Steve          Bird     bird@gmail.com     N94 3M0    5000.00                5
# Steve        Chanel   chanel@gmail.com     N7T 3E6   11072.02               10

# %%
d.loc['Ahmed':'Patton']
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Ismail                  11
# Keller                   7
# Mo                      26
# Moran                   13
# Noor                    22
# Patton                   1

# %%
d.loc[["keller","steve","Mo"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 d.loc[["keller","steve","Mo"]]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# ...

# %%
d.sample(n=2,axis=0)
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
#
#            Years with Bank
# Last Name
# Moran                   13
# Ismail                  11

# %%
d.sample(frac=0.3,axis=0)
# Out:
#           First Name                Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila  Laila.a@hotmail.com     J8Y 3M0   20000.00
# Noor            Kate     kate@hotmail.com     K8N 5H6    5000.00
# Moran           Noah    guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Noor                    22
# Moran                   13

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d.iloc[9]
# Out:
# First Name                      Noah
# Last Name                      Moran
# Email              guutodi@bigwoc.kw
# Postal Code                  K2D 4M9
# Net Worth                    8626.96
# Years with Bank                   13
# Name: 9, dtype: object

# %%
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d.iloc[2:5]
# Out:
#   First Name Last Name             Email Postal Code  Net Worth  \
# 2       Nina    Keller   azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve  chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor  kate@hotmail.com     K8N 5H6    5000.00
#
#    Years with Bank
# 2                7
# 3               10
# 4               22

# %%
d[:4]
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller     azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve    chanel@gmail.com     N7T 3E6   11072.02
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10

# %%
d[3:]
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
d.iloc[[2,4,8]]
# Out:
#   First Name Last Name             Email Postal Code  Net Worth  \
# 2       Nina    Keller   azikez@gahew.mr     S1T 4E6    9072.02
# 4       Kate      Noor  kate@hotmail.com     K8N 5H6    5000.00
# 8     Joseph    Patton    daafeja@boh.jm     M6U 5U7    2629.13
#
#    Years with Bank
# 2                7
# 4               22
# 8                1

# %%
d.iloc[4,0:6]
# Out:
# First Name                     Kate
# Last Name                      Noor
# Email              kate@hotmail.com
# Postal Code                 K8N 5H6
# Net Worth                    5000.0
# Years with Bank                  22
# Name: 4, dtype: object

# %%
d.tail(2)
# Out:
#   First Name Last Name              Email Postal Code  Net Worth  \
# 8     Joseph    Patton     daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran  guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 8                1
# 9               13

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d['Net Worth']=d['Net Worth']+1000

# %%
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    6000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   10072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   12072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    6000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  101000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   51000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   21000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    3629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d['Net Worth']=d['Net Worth'].add(1000)
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    7000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   12000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   11072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   13072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    7000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  102000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   52000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   22000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    4629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9   10626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d['Net Worth(CAD)']=d['Last Name'].mul(1,3)
d
# Out:
#   First Name Last Name                    Email Postal Code   Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0     7000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K    70070.00
# 2       Nina    Keller  Baliyanravi10@gmail.com     S1T 4E6    11072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6    13072.02
# 4       Kate      Noor      Kate.noor@gamil.com     K8N 5H6     7000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  3254656.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8    52000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0    22000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7     4629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    10626.96
#
#    Years with Bank Net Worth(CAD)
# 0                5          Steve
# 1                6          Small
# 2                7         Keller
# 3               10          Steve
# ...

# %%
d.iloc[4,2]='Kate.noor@gamil.com'
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    7000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   12000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   11072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   13072.02
# 4       Kate      Noor      Kate.noor@gamil.com     K8N 5H6    7000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  102000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   52000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   22000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    4629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9   10626.96
#
#    Years with Bank  Net Worth(CAD)
# 0                5         7000.00
# 1                6        12000.00
# 2                7        11072.02
# 3               10        13072.02
# ...

# %%
d.iloc[2,2]="Baliyanravi10@gmail.com"
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    7000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   12000.00
# 2       Nina    Keller  Baliyanravi10@gmail.com     S1T 4E6   11072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   13072.02
# 4       Kate      Noor      Kate.noor@gamil.com     K8N 5H6    7000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  102000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   52000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   22000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    4629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9   10626.96
#
#    Years with Bank  Net Worth(CAD)
# 0                5         7000.00
# 1                6        12000.00
# 2                7        11072.02
# 3               10        13072.02
# ...

# %%
d.iloc[[1,5],[4]]=[70070,3254656]
d
# Out:
#   First Name Last Name                    Email Postal Code   Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0     7000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K    70070.00
# 2       Nina    Keller  Baliyanravi10@gmail.com     S1T 4E6    11072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6    13072.02
# 4       Kate      Noor      Kate.noor@gamil.com     K8N 5H6     7000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  3254656.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8    52000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0    22000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7     4629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    10626.96
#
#    Years with Bank  Net Worth(CAD)
# 0                5         7000.00
# 1                6        12000.00
# 2                7        11072.02
# ...

# %% [markdown]
# # Sorting and ordering

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d.sort_values('Years with Bank',ascending=False,inplace=True)
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
#
#    Years with Bank
# 5               26
# 4               22
# 9               13
# 6               11
# 3               10
# 2                7
# 1                6
# 0                5
# ...

# %%
d.sort_values('Years with Bank',inplace=True)
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank
# 8                1
# 7                3
# 0                5
# 1                6
# 2                7
# 3               10
# 6               11
# 9               13
# ...

# %%
d["Rank"]=d["Net Worth"].rank(ascending=True).astype("int")

# %%
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank  Rank
# 8                1     1
# 7                3     8
# 0                5     2
# 1                6     6
# 2                7     5
# 3               10     7
# ...

# %%
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank  Rank
# 8                1     1
# 7                3     8
# 0                5     2
# 1                6     6
# 2                7     5
# 3               10     7
# ...

# %% [markdown]
# # Pandas Function

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
def Net_Worth(Balance):
    return Balance *1.1

# %%
d['Net Worth']=d['Net Worth'].apply(Net_Worth)
d
# Out:
#   First Name Last Name                    Email Postal Code   Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5500.000
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.000
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9979.222
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   12179.222
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5500.000
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  110000.000
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   55000.000
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   22000.000
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2892.043
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9489.656
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# ...

# %%
d['Name Lenght']=d['First Name'].apply(len)

# %%
d
# Out:
#   First Name Last Name                    Email Postal Code   Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5500.000
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.000
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9979.222
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   12179.222
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5500.000
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  110000.000
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   55000.000
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   22000.000
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2892.043
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9489.656
#
#    Years with Bank  Name Lenght
# 0                5            5
# 1                6            4
# 2                7            4
# 3               10            7
# ...

# %%
d['Years with Bank'].sum()
# Out:
# 104

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x=d[(d['Years with Bank'] >= 10)]
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 3               10
# 4               22
# 5               26
# 6               11
# 9               13

# %%
x=d['Years with Bank'] >= 10
x1=d["Net Worth"] >= 50000
a=d[x & x1]
a
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY   100000.0
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8    50000.0
#
#    Years with Bank
# 5               26
# 6               11

# %%
s=d[(d["First Name"] == 'Heba')]
s
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8    50000.0
#
#    Years with Bank
# 6               11

# %%
mask=d["Last Name"].isin(['Steve','Mo'])
d[mask]
# Out:
#   First Name Last Name             Email Postal Code  Net Worth  \
# 0      Bird      Steve    bird@gmail.com     N94 3M0    5000.00
# 3    Chanel      Steve  chanel@gmail.com     N7T 3E6   11072.02
# 5      Samer        Mo   samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank
# 0                5
# 3               10
# 5               26

# %%
d[d["Net Worth"].between(5000,9000)]
# Out:
#   First Name Last Name              Email Postal Code  Net Worth  \
# 0      Bird      Steve     bird@gmail.com     N94 3M0    5000.00
# 4       Kate      Noor   kate@hotmail.com     K8N 5H6    5000.00
# 9       Noah     Moran  guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 4               22
# 9               13

# %%
g=~d["Last Name"].duplicated(keep=False)
d[g]
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 1                6
# 2                7
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
# DRop
d.drop_duplicates(subset=["Last Name"],inplace=True)

# %%
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
d.drop_duplicates("Last Name",inplace=True)
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x=d['Net Worth'] >= 20000
d.where(x)
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0        NaN       NaN                      NaN         NaN        NaN
# 1        NaN       NaN                      NaN         NaN        NaN
# 2        NaN       NaN                      NaN         NaN        NaN
# 3        NaN       NaN                      NaN         NaN        NaN
# 4        NaN       NaN                      NaN         NaN        NaN
# 5      Samer        Mo          samer@gmail.com     J7H 3HY   100000.0
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8    50000.0
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0    20000.0
# 8        NaN       NaN                      NaN         NaN        NaN
# 9        NaN       NaN                      NaN         NaN        NaN
#
#    Years with Bank
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5             26.0
# 6             11.0
# 7              3.0
# ...

# %%
d=pd.read_csv('Downloads\Human.csv')
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
x=[d.isnull()]

# %%
x
# Out:
# [        Age  Attrition  BusinessTravel  DailyRate  Department  \
#  0     False      False           False      False       False
#  1     False      False           False      False       False
#  2     False      False           False      False       False
#  3     False      False           False      False       False
#  4     False      False           False      False       False
#  ...     ...        ...             ...        ...         ...
#  1465  False      False           False      False       False
#  1466  False      False           False      False       False
#  1467  False      False           False      False       False
#  1468  False      False           False      False       False
#  1469  False      False           False      False       False
#
#        DistanceFromHome  Education  EducationField  EmployeeCount  \
#  0                False      False           False          False
#  1                False      False           False          False
# ...

# %%
d.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
d.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyIncome               3
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
d.dropna(inplace=True)

# %%
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
d=pd.read_csv('Downloads\Human.csv')
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
d.dropna(inplace=True,subset=['MonthlyIncome','PercentSalaryHike'])

# %%
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
import pandas as pd

d=pd.read_csv('Downloads\Human.csv')
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
d['MonthlyIncome'].mean()
# Out:
# 6505.155419222904

# %%
d['MonthlyIncome'].fillna(d['MonthlyIncome'].mean(),inplace = True)

# %%
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
d=pd.read_csv('Downloads\Human.csv')
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1469 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
d["HourlyRate"]=d["HourlyRate"].astype('float64')
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1469 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1470 non-null   float64
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1469 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1470 non-null   float64
# ...

# %%
d["PerformanceRating"]=d["PerformanceRating"].astype("category")
d["RelationshipSatisfaction"]=d["RelationshipSatisfaction"].astype("category")

# %%
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1469 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1470 non-null   float64
# ...

# %%
import pandas as pd

# %%
x=pd.read_csv('Downloads\\ecommerce_sales.csv',encoding='unicode_escape')
x.set_index(keys=["Country",'InvoiceDate'],inplace=True)
x
# Out:
#                                InvoiceNo StockCode  \
# Country        InvoiceDate
# United Kingdom 12/1/2010 8:26     536365    85123A
#                12/1/2010 8:26     536365     71053
#                12/1/2010 8:26     536365    84406B
#                12/1/2010 8:26     536365    84029G
#                12/1/2010 8:26     536365    84029E
# ...                                  ...       ...
# France         12/9/2011 12:50    581587     22613
#                12/9/2011 12:50    581587     22899
#                12/9/2011 12:50    581587     23254
#                12/9/2011 12:50    581587     23255
#                12/9/2011 12:50    581587     22138
#
#                                                         Description  Quantity  \
# Country        InvoiceDate
# United Kingdom 12/1/2010 8:26    WHITE HANGING HEART T-LIGHT HOLDER         6
#                12/1/2010 8:26                   WHITE METAL LANTERN         6
# ...

# %%
s='gdyjgh'
s[3:-1]
# Out:
# 'jg'

# %%
x.index.get_level_values(0)
# Out:
# Index(['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom',
#        'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom',
#        'United Kingdom', 'United Kingdom',
#        ...
#        'France', 'France', 'France', 'France', 'France', 'France', 'France',
#        'France', 'France', 'France'],
#       dtype='object', name='Country', length=541909)

# %%
x.index.set_names(names=['Transaction Location','Transaction Date'],inplace=True)
x
# Out:
#                                       InvoiceNo StockCode  \
# Transaction Location Transaction Date
# United Kingdom       12/1/2010 8:26      536365    85123A
#                      12/1/2010 8:26      536365     71053
#                      12/1/2010 8:26      536365    84406B
#                      12/1/2010 8:26      536365    84029G
#                      12/1/2010 8:26      536365    84029E
# ...                                         ...       ...
# France               12/9/2011 12:50     581587     22613
#                      12/9/2011 12:50     581587     22899
#                      12/9/2011 12:50     581587     23254
#                      12/9/2011 12:50     581587     23255
#                      12/9/2011 12:50     581587     22138
#
#                                                                Description  \
# Transaction Location Transaction Date
# United Kingdom       12/1/2010 8:26     WHITE HANGING HEART T-LIGHT HOLDER
# ...

# %%
x=pd.read_csv('Downloads\\ecommerce_sales.csv',encoding='unicode_escape')
x.set_index(keys=["Country",'InvoiceDate'],inplace=True)
x.sort_index(inplace=True)
x
# Out:
#                            InvoiceNo StockCode  \
# Country     InvoiceDate
# Australia   1/10/2011 9:58    540557     22523
#             1/11/2011 9:47    540700     21581
#             1/11/2011 9:47    540700     22619
#             1/11/2011 9:47    540700    84997B
#             1/11/2011 9:47    540700     20727
# ...                              ...       ...
# Unspecified 9/2/2011 12:17    565303     85227
#             9/2/2011 12:17    565303     22138
#             9/2/2011 12:17    565303     21889
#             9/2/2011 12:17    565303     22550
#             9/2/2011 12:17    565303     23127
#
#                                                   Description  Quantity  \
# Country     InvoiceDate
# Australia   1/10/2011 9:58            CHILDS GARDEN FORK PINK        96
#             1/11/2011 9:47    SKULLS  DESIGN  COTTON TOTE BAG         6
#             1/11/2011 9:47          SET OF 6 SOLDIER SKITTLES         8
# ...

# %%
x=pd.read_csv("Downloads\\ecommerce_sales.csv",encoding='unicode_escape')
x.set_index(keys=["Country","InvoiceDate"],inplace=True)
x.sort_index(inplace=True)
x
# Out:
#                            InvoiceNo StockCode  \
# Country     InvoiceDate
# Australia   1/10/2011 9:58    540557     22523
#             1/11/2011 9:47    540700     21581
#             1/11/2011 9:47    540700     22619
#             1/11/2011 9:47    540700    84997B
#             1/11/2011 9:47    540700     20727
# ...                              ...       ...
# Unspecified 9/2/2011 12:17    565303     85227
#             9/2/2011 12:17    565303     22138
#             9/2/2011 12:17    565303     21889
#             9/2/2011 12:17    565303     22550
#             9/2/2011 12:17    565303     23127
#
#                                                   Description  Quantity  \
# Country     InvoiceDate
# Australia   1/10/2011 9:58            CHILDS GARDEN FORK PINK        96
#             1/11/2011 9:47    SKULLS  DESIGN  COTTON TOTE BAG         6
#             1/11/2011 9:47          SET OF 6 SOLDIER SKITTLES         8
# ...

# %%
x.loc["Australia",'1/11/2011 9:47']
# Out:
#                          InvoiceNo StockCode  \
# Country   InvoiceDate
# Australia 1/11/2011 9:47    540700     21581
#           1/11/2011 9:47    540700     22619
#           1/11/2011 9:47    540700    84997B
#           1/11/2011 9:47    540700     20727
#           1/11/2011 9:47    540700     20726
#           1/11/2011 9:47    540700     22383
#           1/11/2011 9:47    540700     21249
#           1/11/2011 9:47    540700     22378
#           1/11/2011 9:47    540700     22175
#           1/11/2011 9:47    540700     22176
#           1/11/2011 9:47    540700    84997C
#           1/11/2011 9:47    540700     20728
#           1/11/2011 9:47    540700     22382
#           1/11/2011 9:47    540700     21915
#           1/11/2011 9:47    540700     22549
#           1/11/2011 9:47    540700     21578
#           1/11/2011 9:47    540700     21577
#           1/11/2011 9:47    540700     22245
#           1/11/2011 9:47    540700     22244
#
# ...

# %%
x.loc[("Australia",'1/11/2011 9:47'),"UnitPrice"]
# Out:
# Country    InvoiceDate
# Australia  1/11/2011 9:47    2.25
#            1/11/2011 9:47    3.75
#            1/11/2011 9:47    3.75
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    2.95
#            1/11/2011 9:47    0.85
#            1/11/2011 9:47    2.95
#            1/11/2011 9:47    2.95
#            1/11/2011 9:47    3.75
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    1.25
#            1/11/2011 9:47    1.45
#            1/11/2011 9:47    2.25
#            1/11/2011 9:47    2.25
#            1/11/2011 9:47    0.85
#            1/11/2011 9:47    1.95
# Name: UnitPrice, dtype: float64

# %%
x.iloc[0]
# Out:
# InvoiceNo                       540557
# StockCode                        22523
# Description    CHILDS GARDEN FORK PINK
# Quantity                            96
# UnitPrice                         0.85
# CustomerID                     12415.0
# Name: (Australia, 1/10/2011 9:58), dtype: object

# %%
x.iloc[1,4]
# Out:
# 2.25

# %%
x=x.transpose()
x.head(10)
# Out:
# Country                    Australia                                   \
# InvoiceDate           1/10/2011 9:58                   1/11/2011 9:47
# InvoiceNo                     540557                           540700
# StockCode                      22523                            21581
# Description  CHILDS GARDEN FORK PINK  SKULLS  DESIGN  COTTON TOTE BAG
# Quantity                          96                                6
# UnitPrice                       0.85                             2.25
# CustomerID                   12415.0                          12393.0
#
# Country                                                                    \
# InvoiceDate             1/11/2011 9:47                     1/11/2011 9:47
# InvoiceNo                       540700                             540700
# StockCode                        22619                             84997B
# Description  SET OF 6 SOLDIER SKITTLES  RED 3 PIECE RETROSPOT CUTLERY SET
# ...

# %%
x.loc["UnitPrice",("Australia",'1/11/2011 9:47')]
# Out:
# Country    InvoiceDate
# Australia  1/11/2011 9:47    2.25
#            1/11/2011 9:47    3.75
#            1/11/2011 9:47    3.75
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    2.95
#            1/11/2011 9:47    0.85
#            1/11/2011 9:47    2.95
#            1/11/2011 9:47    2.95
#            1/11/2011 9:47    3.75
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    1.65
#            1/11/2011 9:47    1.25
#            1/11/2011 9:47    1.45
#            1/11/2011 9:47    2.25
#            1/11/2011 9:47    2.25
#            1/11/2011 9:47    0.85
#            1/11/2011 9:47    1.95
# Name: UnitPrice, dtype: object

# %%
x.loc["UnitPrice",("Australia",'1/10/2011 9:48'):("Belgium",'1/10/2011 9:58')]
# Out:
# Country    InvoiceDate
# Australia  1/10/2011 9:58    0.85
#            1/11/2011 9:47    2.25
#            1/11/2011 9:47    3.75
#            1/11/2011 9:47    3.75
#            1/11/2011 9:47    1.65
#                              ...
# Bahrain    5/9/2011 13:49    2.95
#            5/9/2011 13:49    2.95
#            5/9/2011 13:49    4.25
#            5/9/2011 13:49    4.25
#            5/9/2011 13:49    4.25
# Name: UnitPrice, Length: 1679, dtype: object

# %%
x=pd.read_csv('Downloads\\ecommerce_sales.csv',encoding='unicode_escape')
x.set_index(keys=["Country","InvoiceDate"],inplace=True)
x
# Out:
#                                InvoiceNo StockCode  \
# Country        InvoiceDate
# United Kingdom 12/1/2010 8:26     536365    85123A
#                12/1/2010 8:26     536365     71053
#                12/1/2010 8:26     536365    84406B
#                12/1/2010 8:26     536365    84029G
#                12/1/2010 8:26     536365    84029E
# ...                                  ...       ...
# France         12/9/2011 12:50    581587     22613
#                12/9/2011 12:50    581587     22899
#                12/9/2011 12:50    581587     23254
#                12/9/2011 12:50    581587     23255
#                12/9/2011 12:50    581587     22138
#
#                                                         Description  Quantity  \
# Country        InvoiceDate
# United Kingdom 12/1/2010 8:26    WHITE HANGING HEART T-LIGHT HOLDER         6
#                12/1/2010 8:26                   WHITE METAL LANTERN         6
# ...

# %%
x=x.swaplevel()
x
# Out:
#                                InvoiceNo StockCode  \
# Country        InvoiceDate
# United Kingdom 12/1/2010 8:26     536365    85123A
#                12/1/2010 8:26     536365     71053
#                12/1/2010 8:26     536365    84406B
#                12/1/2010 8:26     536365    84029G
#                12/1/2010 8:26     536365    84029E
# ...                                  ...       ...
# France         12/9/2011 12:50    581587     22613
#                12/9/2011 12:50    581587     22899
#                12/9/2011 12:50    581587     23254
#                12/9/2011 12:50    581587     23255
#                12/9/2011 12:50    581587     22138
#
#                                                         Description  Quantity  \
# Country        InvoiceDate
# United Kingdom 12/1/2010 8:26    WHITE HANGING HEART T-LIGHT HOLDER         6
#                12/1/2010 8:26                   WHITE METAL LANTERN         6
# ...

# %%
d=x.swaplevel()
d
# Out:
#                                InvoiceNo StockCode  \
# InvoiceDate     Country
# 12/1/2010 8:26  United Kingdom    536365    85123A
#                 United Kingdom    536365     71053
#                 United Kingdom    536365    84406B
#                 United Kingdom    536365    84029G
#                 United Kingdom    536365    84029E
# ...                                  ...       ...
# 12/9/2011 12:50 France            581587     22613
#                 France            581587     22899
#                 France            581587     23254
#                 France            581587     23255
#                 France            581587     22138
#
#                                                         Description  Quantity  \
# InvoiceDate     Country
# 12/1/2010 8:26  United Kingdom   WHITE HANGING HEART T-LIGHT HOLDER         6
#                 United Kingdom                  WHITE METAL LANTERN         6
# ...

# %%
x=d.swaplevel()
x
# Out:
#                                InvoiceNo StockCode  \
# Country        InvoiceDate
# United Kingdom 12/1/2010 8:26     536365    85123A
#                12/1/2010 8:26     536365     71053
#                12/1/2010 8:26     536365    84406B
#                12/1/2010 8:26     536365    84029G
#                12/1/2010 8:26     536365    84029E
# ...                                  ...       ...
# France         12/9/2011 12:50    581587     22613
#                12/9/2011 12:50    581587     22899
#                12/9/2011 12:50    581587     23254
#                12/9/2011 12:50    581587     23255
#                12/9/2011 12:50    581587     22138
#
#                                                         Description  Quantity  \
# Country        InvoiceDate
# United Kingdom 12/1/2010 8:26    WHITE HANGING HEART T-LIGHT HOLDER         6
#                12/1/2010 8:26                   WHITE METAL LANTERN         6
# ...
