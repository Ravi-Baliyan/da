# %%
import pandas as pd
import numpy as np
import html as hl

# %%
df = pd.read_html('https://www.ssa.gov/oact/progdata/nra.html')
df
# Out:
# [                                        Year of birth  \
#  0                                      1937 and prior
#  1                                                1938
#  2                                                1939
#  3                                                1940
#  4                                                1941
#  5                                                1942
#  6                                             1943-54
#  7                                                1955
#  8                                                1956
#  9                                                1957
#  10                                               1958
#  11                                               1959
#  12                                     1960 and later
#  13  Notes: 1. Persons born on January 1 of any yea...
#
#                                                    Age
#  0                                                  65
# ...

# %%
x=int(input("enter the number: "))
y=int(input("Enter the  number: "))
z=int(input("Enter the number: "))
if x<y>z:
    print(,"y is Smallest")
elif y<x<z:
    print(y,"Y is Smallest")
else:
    print(z,"Z is Smallest")
# Out:
# enter the number: 12
# Enter the  number: 22
# Enter the number: 32
# 12 X is Smallest

# %%
n=10
k=15
print(n | k)
# Out:
# 15

# %%
import pandas as pd

# %%
d=pd.read_csv('Downloads\\bank_client_information.csv')

# %%
d
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x=d.set_index(['Last Name'])

# %%
x
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#            Years with Bank
# Last Name
# Steve                    5
# Small                    6
# Keller                   7
# Steve                   10
# Noor                    22
# ...

# %%
d1=x.reset_index()

# %%
d1
# Out:
#   Last Name First Name                    Email Postal Code  Net Worth  \
# 0     Steve      Bird            bird@gmail.com     N94 3M0    5000.00
# 1     Small       Noah       nsmall@hotmail.com     N8S 14K   10000.00
# 2    Keller       Nina          azikez@gahew.mr     S1T 4E6    9072.02
# 3     Steve    Chanel          chanel@gmail.com     N7T 3E6   11072.02
# 4      Noor       Kate         kate@hotmail.com     K8N 5H6    5000.00
# 5        Mo      Samer          samer@gmail.com     J7H 3HY  100000.00
# 6    Ismail       Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7     Ahmed      Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8    Patton     Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# 9     Moran       Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
d.insert(3,'Secret_code',value=['yo','yoyo','hunny','singh','paji','pg','degree','college','oyo','gate'])

# %%
d
# Out:
#   First Name Last Name                    Email Secret_code Postal Code  \
# 0      Bird      Steve           bird@gmail.com          yo     N94 3M0
# 1       Noah     Small       nsmall@hotmail.com        yoyo     N8S 14K
# 2       Nina    Keller          azikez@gahew.mr       hunny     S1T 4E6
# 3    Chanel      Steve         chanel@gmail.com       singh     N7T 3E6
# 4       Kate      Noor         kate@hotmail.com        paji     K8N 5H6
# 5      Samer        Mo          samer@gmail.com          pg     J7H 3HY
# 6       Heba    Ismail  heba.ismail@hotmail.com      degree     K8Y 3M8
# 7      Laila     Ahmed      Laila.a@hotmail.com     college     J8Y 3M0
# 8     Joseph    Patton           daafeja@boh.jm         oyo     M6U 5U7
# 9       Noah     Moran        guutodi@bigwoc.kw        gate     K2D 4M9
#
#    Net Worth  Years with Bank
# 0    5000.00                5
# 1   10000.00                6
# 2    9072.02                7
# 3   11072.02               10
# ...

# %%
x["Email"]
# Out:
# Last Name
# Steve              bird@gmail.com
# Small          nsmall@hotmail.com
# Keller            azikez@gahew.mr
# Steve            chanel@gmail.com
# Noor             kate@hotmail.com
# Mo                samer@gmail.com
# Ismail    heba.ismail@hotmail.com
# Ahmed         Laila.a@hotmail.com
# Patton             daafeja@boh.jm
# Moran           guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
d.drop(["Secret_code"],axis=1)
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
x=d[["First Name","Net Worth"]]

# %%
x
# Out:
#   First Name  Net Worth
# 0      Bird     5000.00
# 1       Noah   10000.00
# 2       Nina    9072.02
# 3    Chanel    11072.02
# 4       Kate    5000.00
# 5      Samer  100000.00
# 6       Heba   50000.00
# 7      Laila   20000.00
# 8     Joseph    2629.13
# 9       Noah    8626.96

# %%
d.loc[0]
# Out:
# First Name                  Bird
# Last Name                   Steve
# Email              bird@gmail.com
# Secret_code                    yo
# Postal Code               N94 3M0
# Net Worth                  5000.0
# Years with Bank                 5
# Name: 0, dtype: object

# %%
d.loc[0:2]
# Out:
#   First Name Last Name               Email Secret_code Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com          yo     N94 3M0    5000.00
# 1       Noah     Small  nsmall@hotmail.com        yoyo     N8S 14K   10000.00
# 2       Nina    Keller     azikez@gahew.mr       hunny     S1T 4E6    9072.02
#
#    Years with Bank
# 0                5
# 1                6
# 2                7

# %%
d.loc[0:4]
# Out:
#   First Name Last Name               Email Secret_code Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com          yo     N94 3M0    5000.00
# 1       Noah     Small  nsmall@hotmail.com        yoyo     N8S 14K   10000.00
# 2       Nina    Keller     azikez@gahew.mr       hunny     S1T 4E6    9072.02
# 3    Chanel      Steve    chanel@gmail.com       singh     N7T 3E6   11072.02
# 4       Kate      Noor    kate@hotmail.com        paji     K8N 5H6    5000.00
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22

# %%
d.loc[0]['First Name'][::-1]
# Out:
# ' driB'

# %%
d["First Name"]
# Out:
# 0      Bird
# 1       Noah
# 2       Nina
# 3    Chanel
# 4       Kate
# 5      Samer
# 6       Heba
# 7      Laila
# 8     Joseph
# 9       Noah
# Name: First Name, dtype: object

# %%
for i in d["First Name"]:
    d["First Name"][::-1]

# %%
d
# Out:
#   First Name Last Name                    Email Secret_code Postal Code  \
# 0      Bird      Steve           bird@gmail.com          yo     N94 3M0
# 1       Noah     Small       nsmall@hotmail.com        yoyo     N8S 14K
# 2       Nina    Keller          azikez@gahew.mr       hunny     S1T 4E6
# 3    Chanel      Steve         chanel@gmail.com       singh     N7T 3E6
# 4       Kate      Noor         kate@hotmail.com        paji     K8N 5H6
# 5      Samer        Mo          samer@gmail.com          pg     J7H 3HY
# 6       Heba    Ismail  heba.ismail@hotmail.com      degree     K8Y 3M8
# 7      Laila     Ahmed      Laila.a@hotmail.com     college     J8Y 3M0
# 8     Joseph    Patton           daafeja@boh.jm         oyo     M6U 5U7
# 9       Noah     Moran        guutodi@bigwoc.kw        gate     K2D 4M9
#
#    Net Worth  Years with Bank
# 0    5000.00                5
# 1   10000.00                6
# 2    9072.02                7
# 3   11072.02               10
# ...

# %%
for i in d.index:
    d['First Name'][i]=d['First Name'][i][::-1]
# Out:
# C:\Users\baliy\AppData\Local\Temp\ipykernel_25724\1562888462.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['First Name'][i]=d['First Name'][i][::-1]

# %%
d
# Out:
#   First Name Last Name                    Email Secret_code Postal Code  \
# 0       driB     Steve           bird@gmail.com          yo     N94 3M0
# 1       haoN     Small       nsmall@hotmail.com        yoyo     N8S 14K
# 2       aniN    Keller          azikez@gahew.mr       hunny     S1T 4E6
# 3     lenahC     Steve         chanel@gmail.com       singh     N7T 3E6
# 4       etaK      Noor         kate@hotmail.com        paji     K8N 5H6
# 5      remaS        Mo          samer@gmail.com          pg     J7H 3HY
# 6       abeH    Ismail  heba.ismail@hotmail.com      degree     K8Y 3M8
# 7      aliaL     Ahmed      Laila.a@hotmail.com     college     J8Y 3M0
# 8     hpesoJ    Patton           daafeja@boh.jm         oyo     M6U 5U7
# 9       haoN     Moran        guutodi@bigwoc.kw        gate     K2D 4M9
#
#    Net Worth  Years with Bank
# 0    5000.00                5
# 1   10000.00                6
# 2    9072.02                7
# 3   11072.02               10
# ...

# %%
import pandas as pd

# %%
x=pd.read_csv("C:\\Users\\baliy\\Downloads\\bank_client_information.csv")

# %%
x
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
# set_index
# Reset_index                            
# drop
# loc
# iloc
# ffill
# bfill
# filtering
# delete
# groupby
# concat
# heat
# tail
# Metadata
# describe
# insert
# null clean
# check null values
# aggregate functions e.g sum()....count()....avg().....ununique().....mean().....median().....max().....min()
# selecting columns
# Adding columns
# You can perform swaplevel as follows:

# %%
x=pd.read_csv("C:\\Users\\baliy\\Downloads\\Human.csv")

# %%
x
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
x.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyIncome               3
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
x.fillna(method='ffill',inplace=True)

# %%
x
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
x.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
d=x[(x['DistanceFromHome']>=10)]

# %%
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1459   29        No      Travel_Rarely       1378  Research & Development
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
d['Age']=d['Age']+28
# Out:
# C:\Users\baliy\AppData\Local\Temp\ipykernel_2440\3920552863.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Age']=d['Age']+28

# %%
d
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 7      58        No      Travel_Rarely       1358  Research & Development
# 8      66        No  Travel_Frequently        216  Research & Development
# 9      64        No      Travel_Rarely       1299  Research & Development
# 10     63        No      Travel_Rarely        809  Research & Development
# 11     57        No      Travel_Rarely        153  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1459   57        No      Travel_Rarely       1378  Research & Development
# 1460   57        No      Travel_Rarely        468  Research & Development
# 1461   78       Yes      Travel_Rarely        410                   Sales
# 1462   67        No      Travel_Rarely        722                   Sales
# 1465   64        No  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
x
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
x['HourlyRate']=x['HourlyRate'].astype('float64')

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   float64
# ...
