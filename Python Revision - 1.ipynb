# %%
import requests 
from bs4 import BeautifulSoup

# %%
url='https://www.icccricketschedule.com/ipl-2021-schedule-team-venue-time-table-pdf-point-table-ranking-winning-prediction/'

# %%
r=requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(r.content,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html >
#
# <!--[if IE 8]>    <html class="ie8" lang="en-US" prefix="og: https://ogp.me/ns#"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en-US" prefix="og: https://ogp.me/ns#"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-US" prefix="og: https://ogp.me/ns#"> <!--<![endif]-->
# <head>
# <title>IPL 2021 Schedule, Team, Venue, Time Table, PDF, Point Table, Ranking &amp; Winning Prediction</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.icccricketschedule.com/xmlrpc.php" rel="pingback"/>
# <link href="https://icccricketschedule.gumlet.io" rel="dns-prefetch"/>
# <meta content="VIVO IPL 2021 has been scheduled between 19 September 2021 and 15 October 2021 in the United Arab Emirates. The VIVO IPL 2021 is the 14th season of the" name="description">
# ...

# %%
y=soup.find('h1',class_='entry-title')

# %%
for i in y:
    print(i)
# Out:
# IPL 2021 Schedule, Team, Venue, Time Table, PDF, Point Table, Ranking & Winning Prediction

# %%
a=soup.find('tbody').find_all('td')

# %%
for i in a:
    print(i)
# Out:
# <td>30</td>
# <td><a href="https://www.icccricketschedule.com/csk-full-players-list-in-ipl-2022-retained-released-updated-squad-after-mega-auction/">CSK</a> Vs MI</td>
# <td>19-Sep-21</td>
# <td>07:30 PM</td>
# <td>Dubai</td>
# <td>31</td>
# <td><a href="https://www.icccricketschedule.com/kkr-full-players-list-in-ipl-2022-retained-released-updated-squad/">KKR</a> Vs RCB</td>
# <td>20-Sep-21</td>
# <td>07:30 PM</td>
# <td>Abu Dhabi</td>
# <td>32</td>
# <td><a href="https://www.icccricketschedule.com/pbks-full-players-list-in-ipl-2022-retained-released-updated-squad/">PBKS</a> Vs RR</td>
# <td>21-Sep-21</td>
# <td>07:30 PM</td>
# <td>Dubai</td>
# <td>33</td>
# <td><a href="https://www.icccricketschedule.com/dc-full-players-list-in-ipl-2022-retained-released-updated-squad/">DC</a> Vs <a href="https://www.icccricketschedule.com/srh-full-players-list-in-ipl-2022-retained-released-updated-squad/">SRH</a></td>
# <td>22-Sep-21</td>
# <td>07:30 PM</td>
# <td>Dubai</td>
# <td>34</td>
# ...

# %%
image=soup.find('img',src='https://icccricketschedule.gumlet.io/wp-content/uploads/2021/09/ipl_2021_schedule_news.jpg?compress=true&quality=80&w=600&dpr=1.5')

# %%
image

# %%
a=['1','4','3','3']
b=a[1]+a[2]+a[3]
#output=433
print(b)
# Out:
# 433

# %%
x='Interview'
print(x.replace('e','',1))
# Out:
# Intrview

# %%
a=input("enter the name ")
if a==a[::-1]:             
    print("palindrom")    #121 313 1331
else:
    print("not a palindrome")
# Out:
# enter the name 565
# palindrom

# %%
#Q3.Find the last position of a given substring
x="Emma is a data scientist who knows Python. Emma works at google."
print(x.rfind(' '))
print(x.rindex('e'))
# Out:
# 56
# 62
