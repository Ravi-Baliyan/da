# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=pd.read_csv("C:\\Users\\baliy\\Downloads\\First_Quote.csv")

# %%
x
# Out:
#               Zone                                       Site Address  \
# 0        Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1        Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2        Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 3        Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4        Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...            ...                                                ...
# 5164  Not assigned  Opp Polytechnic, Kosamba Road, Bhagdawada / Va...
# 5165  Not assigned  Samrat House, Opp Meera Society 2nd gate, Shan...
# 5166  Not assigned  alwarthirunagar, gandhi road, valasaravakkam /...
# 5167  Not assigned                                 karnal 132001 / IN
# 5168  Not assigned      naomi konambai, edappally / Kochi 682024 / IN
#
#               Region  Opportunity ID Opp Created On Enquiry Created By  \
# ...

# %%
x.set_index('Region',inplace=True)

# %%
x
# Out:
#                         Zone  \
# Region
# Bangalore City     Bangalore
# Bangalore City     Bangalore
# Bangalore City     Bangalore
# Bangalore City     Bangalore
# Bangalore City     Bangalore
# ...                      ...
# #               Not assigned
# #               Not assigned
# #               Not assigned
# #               Not assigned
# #               Not assigned
#
#                                                      Site Address  \
# Region
# Bangalore City  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# Bangalore City  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# Bangalore City  # A 1603 Brigade Metro Polis / Banglore 560067...
# Bangalore City  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# Bangalore City  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...                                                           ...
# #               Opp Polytechnic, Kosamba Road, Bhagdawada / Va...
# ...

# %%
x.reset_index('Region',inplace=True)

# %%
x
# Out:
#               Region          Zone  \
# 0     Bangalore City     Bangalore
# 1     Bangalore City     Bangalore
# 2     Bangalore City     Bangalore
# 3     Bangalore City     Bangalore
# 4     Bangalore City     Bangalore
# ...              ...           ...
# 5164               #  Not assigned
# 5165               #  Not assigned
# 5166               #  Not assigned
# 5167               #  Not assigned
# 5168               #  Not assigned
#
#                                            Site Address  Opportunity ID  \
# 0     # 6/1 Osborne Road,1st Cross / Banglore 560067...          563226
# 1     # 607 16th D ain Benaka Towers Kodihalli. / Ba...          555286
# 2     # A 1603 Brigade Metro Polis / Banglore 560067...          560260
# 3     # C 304 Varacious Lansdale,Varthur Kodi,Whitef...          556991
# 4     # G14 DC Capital,kadubeesanahalli / Banglore 5...          563153
# ...                                                 ...             ...
# ...

# %%
x['Site Address']
# Out:
# 0       # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1       # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2       # A 1603 Brigade Metro Polis / Banglore 560067...
# 3       # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4       # G14 DC Capital,kadubeesanahalli / Banglore 5...
#                               ...
# 5164    Opp Polytechnic, Kosamba Road, Bhagdawada / Va...
# 5165    Samrat House, Opp Meera Society 2nd gate, Shan...
# 5166    alwarthirunagar, gandhi road, valasaravakkam /...
# 5167                                   karnal 132001 / IN
# 5168        naomi konambai, edappally / Kochi 682024 / IN
# Name: Site Address, Length: 5169, dtype: object

# %%
x[0:3]
# Out:
#            Region       Zone  \
# 0  Bangalore City  Bangalore
# 1  Bangalore City  Bangalore
# 2  Bangalore City  Bangalore
#
#                                         Site Address  Opportunity ID  \
# 0  # 6/1 Osborne Road,1st Cross / Banglore 560067...          563226
# 1  # 607 16th D ain Benaka Towers Kodihalli. / Ba...          555286
# 2  # A 1603 Brigade Metro Polis / Banglore 560067...          560260
#
#   Opp Created On Enquiry Created By       Customer Name  Contact Number  \
# 0     24.06.2022             Dealer        Mr H.Karthik  +91 9980072721
# 1     06.06.2022              Sales         Sajan Hegde  +91 9987115499
# 2     18.06.2022             Dealer  Ms Shalini Jaiswal  +91 9901820022
#
#                     E-Mail       City  ...     Gross Value       Net Value  \
# 0        karthik@insri.com   Banglore  ...  278,229.81 INR  230,620.18 INR
# 1  roopasharma22@gmail.com  Bangalore  ...  146,411.38 INR  118,024.77 INR
# ...

# %%
x.head(3)
# Out:
#            Region       Zone  \
# 0  Bangalore City  Bangalore
# 1  Bangalore City  Bangalore
# 2  Bangalore City  Bangalore
#
#                                         Site Address  Opportunity ID  \
# 0  # 6/1 Osborne Road,1st Cross / Banglore 560067...          563226
# 1  # 607 16th D ain Benaka Towers Kodihalli. / Ba...          555286
# 2  # A 1603 Brigade Metro Polis / Banglore 560067...          560260
#
#   Opp Created On Enquiry Created By       Customer Name  Contact Number  \
# 0     24.06.2022             Dealer        Mr H.Karthik  +91 9980072721
# 1     06.06.2022              Sales         Sajan Hegde  +91 9987115499
# 2     18.06.2022             Dealer  Ms Shalini Jaiswal  +91 9901820022
#
#                     E-Mail       City  ...     Gross Value       Net Value  \
# 0        karthik@insri.com   Banglore  ...  278,229.81 INR  230,620.18 INR
# 1  roopasharma22@gmail.com  Bangalore  ...  146,411.38 INR  118,024.77 INR
# ...

# %%
x.tail(1)
# Out:
#      Region          Zone                                   Site Address  \
# 5168      #  Not assigned  naomi konambai, edappally / Kochi 682024 / IN
#
#       Opportunity ID Opp Created On Enquiry Created By Customer Name  \
# 5168          504753     25.01.2022     Connect Center     Noumin AA
#
#       Contact Number               E-Mail   City  ...   Gross Value  \
# 5168  +91 9995991099  aa.noumin@gmail.com  Kochi  ...  8,942.60 INR
#
#          Net Value Basic Value (at DP) Standard Discount 1st Discount Given  \
# 5168  6,655.55 INR        4,871.20 INR          0.00 INR           0.00 INR
#
#      Closed Customer value Closed Basic value MSC Material value  \
# 5168              0.00 INR           0.00 INR           0.00 INR
#
#      MSC Gross Value Lost Price
# 5168            0.00       0.00
#
# [1 rows x 63 columns]

# %%
x.describe()
# Out:
#        Opportunity ID       Pincode  No. of Sales Quote
# count     5169.000000  5.169000e+03         5169.000000
# mean    552966.387502  4.117436e+05            1.654285
# std      34147.282878  2.326516e+05            1.234596
# min      17146.000000  1.100010e+05            1.000000
# 25%     554545.000000  2.013010e+05            1.000000
# 50%     557712.000000  4.140030e+05            1.000000
# 75%     561063.000000  5.601030e+05            2.000000
# max     566071.000000  6.823035e+06           34.000000

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5169 entries, 0 to 5168
# Data columns (total 63 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Region                            5169 non-null   object
#  1   Zone                              5169 non-null   object
#  2   Site Address                      5169 non-null   object
#  3   Opportunity ID                    5169 non-null   int64
#  4   Opp Created On                    5169 non-null   object
#  5   Enquiry Created By                5169 non-null   object
#  6   Customer Name                     5169 non-null   object
#  7   Contact Number                    5169 non-null   object
#  8   E-Mail                            5169 non-null   object
#  9   City                              5169 non-null   object
#  10  State                             5169 non-null   object
# ...

# %%
for i in x['Gross Value']:
    print(i)
    print(type(i))
# Out:
# 278,229.81 INR
# <class 'str'>
# 146,411.38 INR
# <class 'str'>
# 213,905.51 INR
# <class 'str'>
# 25,984.34 INR
# <class 'str'>
# 90,759.49 INR
# <class 'str'>
# 843,547.19 INR
# <class 'str'>
# 563,265.50 INR
# <class 'str'>
# 1,392,748.29 INR
# <class 'str'>
# 156,517.69 INR
# <class 'str'>
# 5,473,740.02 INR
# <class 'str'>
# 262,166.63 INR
# <class 'str'>
# 67,618.01 INR
# <class 'str'>
# 35,502.89 INR
# <class 'str'>
# 224,138.84 INR
# <class 'str'>
# 271,227.56 INR
# <class 'str'>
# 561,571.27 INR
# <class 'str'>
# 419,021.57 INR
# <class 'str'>
# 882,058.07 INR
# <class 'str'>
# 132,478.78 INR
# <class 'str'>
# 1,317,723.46 INR
# <class 'str'>
# 252,461.89 INR
# <class 'str'>
# 1,133,230.76 INR
# <class 'str'>
# 97,210.41 INR
# <class 'str'>
# 1,199,545.23 INR
# <class 'str'>
# 477,101.15 INR
# <class 'str'>
# 160,526.29 INR
# <class 'str'>
# 226,840.51 INR
# <class 'str'>
# 1,371,032.08 INR
# <class 'str'>
# 870,040.47 INR
# <class 'str'>
# 881,535.86 INR
# <class 'str'>
# ...

# %%
x.isnull().sum()
# Out:
# Region                   0
# Zone                     0
# Site Address             0
# Opportunity ID           0
# Opp Created On           0
#                         ..
# Closed Customer value    0
# Closed Basic value       0
# MSC Material value       0
# MSC Gross Value          0
# Lost Price               0
# Length: 63, dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv("C:\\Users\\baliy\\Downloads\\First_Quote.csv")

# %%
x
# Out:
#               Zone                                       Site Address  \
# 0        Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1        Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2        Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 3        Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4        Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...            ...                                                ...
# 5164  Not assigned  Opp Polytechnic, Kosamba Road, Bhagdawada / Va...
# 5165  Not assigned  Samrat House, Opp Meera Society 2nd gate, Shan...
# 5166  Not assigned  alwarthirunagar, gandhi road, valasaravakkam /...
# 5167  Not assigned                                 karnal 132001 / IN
# 5168  Not assigned      naomi konambai, edappally / Kochi 682024 / IN
#
#               Region  Opportunity ID Opp Created On Enquiry Created By  \
# ...

# %%
y=pd.read_csv('Downloads\\Close_Date.csv')

# %%
y
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  "Channabasava", 1st cross, near Mission compou...
# 1         Bangalore  # 108-F9, 6th cross, 2nd main, HGH layout / Ba...
# 2         Bangalore  # 3A Fair Field Appt,Benson Town / Banglore 56...
# 3         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 4         Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...             ...                                                ...
# 10147  Not assigned     Village Hyatpur Rurki / Navashehar 144532 / IN
# 10148  Not assigned  Vipanchika house ,SN Junction / Trippunithura ...
# 10149  Not assigned               collecterate road / Rewa 486001 / IN
# 10150  Not assigned                                 karnal 132001 / IN
# 10151  Not assigned                                  satna 485001 / IN
#
#                Region  Opportunity ID Opp Created On Enquiry Created By  \
# ...

# %%
z=pd.read_csv('Downloads\\Opp_Created.csv')

# %%
z
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  # 209-99 1st Main Rd, NGEF Layout, Krishnaiyya...
# 1         Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 2         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 3         Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 4         Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# ...             ...                                                ...
# 10916  Not assigned                       ring road / Rewa 486001 / IN
# 10917  Not assigned                    roopengarh, / ajmer 305814 / IN
# 10918  Not assigned                sanjay nagar / Bareilly 243005 / IN
# 10919  Not assigned                                        shekta / IN
# 10920  Not assigned  village post gaighat dist ballia / Ballia 2772...
#
#                Region  Opportunity ID Opp Created On  Enquiry Created By  \
# ...

# %%
d=pd.concat([x,y,z])

# %%
d
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2         Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 3         Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4         Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...             ...                                                ...
# 10916  Not assigned                       ring road / Rewa 486001 / IN
# 10917  Not assigned                    roopengarh, / ajmer 305814 / IN
# 10918  Not assigned                sanjay nagar / Bareilly 243005 / IN
# 10919  Not assigned                                        shekta / IN
# 10920  Not assigned  village post gaighat dist ballia / Ballia 2772...
#
#                Region  Opportunity ID Opp Created On  Enquiry Created By  \
# ...

# %%
d.replace(['#',np.nan],inplace=True)

# %%
d
# Out:
#                Zone                                       Site Address  \
# 0         Bangalore  # 6/1 Osborne Road,1st Cross / Banglore 560067...
# 1         Bangalore  # 607 16th D ain Benaka Towers Kodihalli. / Ba...
# 2         Bangalore  # A 1603 Brigade Metro Polis / Banglore 560067...
# 3         Bangalore  # C 304 Varacious Lansdale,Varthur Kodi,Whitef...
# 4         Bangalore  # G14 DC Capital,kadubeesanahalli / Banglore 5...
# ...             ...                                                ...
# 10916  Not assigned                       ring road / Rewa 486001 / IN
# 10917  Not assigned                    roopengarh, / ajmer 305814 / IN
# 10918  Not assigned                sanjay nagar / Bareilly 243005 / IN
# 10919  Not assigned                                        shekta / IN
# 10920  Not assigned  village post gaighat dist ballia / Ballia 2772...
#
#                Region  Opportunity ID Opp Created On  Enquiry Created By  \
# ...

# %%
a=d.isna().sum()
a1=d.columns
for i,j in zip(a,a1):
    print(i,j)
# Out:
# 0 Zone
# 0 Site Address
# 0 Region
# 0 Opportunity ID
# 0 Opp Created On
# 0 Enquiry Created By
# 0 Customer Name
# 0 Contact Number
# 0 E-Mail
# 0 City
# 0 State
# 0 Pincode
# 0 Source of Enq
# 0 Sales Owner
# 0 Sales Owner ID
# 0 CSE Name
# 0 Nature of Work
# 0 Influencer Involved
# 0 Influencer Name
# 0 First Interaction Date
# 0 Site Visit Date
# 0 Persuasion Date
# 0 Showroom Visit Date
# 0 Boq Received Date
# 0 Product Category
# 0 Client expectation Price Bracket
# 0 Quote Segment
# 0 WM Order Type
# 0 WM Quote ID
# 0 First Quote Date
# 0 Latest Quote Date
# 0 Quote Review Date
# 0 Expected Closure Month
# 0 No. of Sales Quote
# 0 Won/Lost/In Process
# 0 Last Progression Stage
# 0 Order in Hand
# 0 Order in Hand Date
# 0 Status-Hot / Warm/ Cold
# 0 Remarks
# 0 Main Competitor
# 0 Reason for Status
# 0 Expected Site Readiness Date
# 0 1st Discount Given Date
# 0 2nd Discount Given Date
# 0 Order Basis to Fenesta
# 0 Quote Area
# 0 Next Step
# 0 Next Step Due Date
# ...
