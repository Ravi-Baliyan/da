# %%
import pandas as pd
import numpy as np

# %%
l=[1,2,3,45,5]
x=pd.Series(l)

# %%
import numpy as np

# %%
l=[1,2,3,45,5,6,8,10]
x=pd.Series([i for i in l if( i%2==0 )], index=np.arange(1,5))
x
# Out:
# 1     2
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
l=[1,2,3,45,5,6,8,10]
x=pd.Series([i for i in l if i%2==0])
y=pd.Series(enumerate(x,start=1))
y
# Out:
# 0     (1, 2)
# 1     (2, 6)
# 2     (3, 8)
# 3    (4, 10)
# dtype: object

# %%
a=pd.Series
a
# Out:
# pandas.core.series.Series

# %%
n=10
k=15
print(n | k)
# Out:
# 15

# %%
x=int(input("Enter the number: "))
while x:
    b=x%10
    x=x//10
    if b==1:
        print('One',end=' ')
    elif b==2:
        print('Two',end=' ')
    elif b==3:
        print('Three',end=' ')
    elif b==4:
        print('four',end=' ')
    elif b==5:
        print('five',end=' ')
    elif b==6:
        print('six',end=' ')
    elif b==7:
        print('seven',end=' ')
    elif b==8:
        print('eight',end=' ')
    elif b==9:
        print('nine',end=' ')
    else:
        print('zero',end=' ')
# Out:
# Enter the number: 12345
# five four Three Two One

# %%
import pandas as pd

# %%
x={'name':[1,2,3,4,5],
  'age':[21,21,22,23,25],
  'members':[5,4,3,2,1]}
a=pd.DataFrame(x)
a
# Out:
#    name  age  members
# 0     1   21        5
# 1     2   21        4
# 2     3   22        3
# 3     4   23        2
# 4     5   25        1

# %%
# To get the values of a name column
x=pd.DataFrame(a,columns=['name'])
x
# Out:
#    name
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5

# %%
y=pd.DataFrame(a,columns=['age'])
y
# Out:
#    age
# 0   21
# 1   21
# 2   22
# 3   23
# 4   25

# %%
y=pd.DataFrame(a,columns=['age','members'])
y
# Out:
#    age  members
# 0   21        5
# 1   21        4
# 2   22        3
# 3   23        2
# 4   25        1

# %%
b=pd.DataFrame(x,columns=['age'],index=['a','b','c','d','e'])
b
# Out:
#    age
# a   21
# b   21
# c   22
# d   23
# e   25

# %%
b.reset_index(inplace=True)
b
# Out:
#   index  age
# 0     a   21
# 1     b   21
# 2     c   22
# 3     d   23
# 4     e   25

# %%
print(b['age'][3])
# Out:
# 23

# %%
y.insert(0,'index',[1,2,3,4,5])

# %%
y
# Out:
#    index  age  members
# 0      1   21        5
# 1      2   21        4
# 2      3   22        3
# 3      4   23        2
# 4      5   25        1

# %%
y.set_index('index',inplace=True)

# %%
y
# Out:
#        age  members
# index
# 1       21        5
# 2       21        4
# 3       22        3
# 4       23        2
# 5       25        1

# %%
import pandas as pd
a=pd.DataFrame(x,columns=(['age']))
a
# Out:
#    age
# 0   21
# 1   21
# 2   22
# 3   23
# 4   25

# %%
bin(30)
# Out:
# '0b11110'

# %%
bin(12)
# Out:
# '0b1100'

# %%
import pandas as pd

# %%
df=pd.read_csv('Downloads\\bank_client_information.csv')

# %%
df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
df["Age"]=[1,2,3,4,5,5,6,7,78,5]

# %%
df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Age
# 0                5    1
# 1                6    2
# 2                7    3
# 3               10    4
# 4               22    5
# 5               26    5
# ...

# %%
d='python'
d[-6:]
d[0::]
# Out:
# 'python'

# %%
d[-6:-1]
# Out:
# 'pytho'

# %%
d[-6:6]
# Out:
# 'python'

# %%
d="Uttam singh python"
d[-5:]
# Out:
# 'ython'

# %%
x='hghz \N hsgdh \n hgvxh'
x
# Out:
#   Input In [29]
#     x='hghz \N hsgdh \n hgvxh'
#                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 5-6: malformed \N character escape

# %%
print(x)
# Out:
# hghz
#  hsgdh
#  hgvxh

# %%
x
# Out:
# 'hghz \n hsgdh \n hgvxh'

# %%
f='gySZHG \ N hsg'

# %%
import numpy as np
import pandas as pd

# %%
x=pd.read_csv("Downloads\S_P500_Prices.csv")

# %%
x
# Out:
#             sp500
# 0     1295.500000
# 1     1289.089966
# 2     1293.670044
# 3     1308.040039
# 4     1314.500000
# ...           ...
# 2154  3327.770020
# 2155  3349.159912
# 2156  3351.280029
# 2157  3360.469971
# 2158  3333.689941
#
# [2159 rows x 1 columns]

# %%
x.head(5)
# Out:
#          sp500
# 0  1295.500000
# 1  1289.089966
# 2  1293.670044
# 3  1308.040039
# 4  1314.500000

# %%
x.tail(4)
# Out:
#             sp500
# 2155  3349.159912
# 2156  3351.280029
# 2157  3360.469971
# 2158  3333.689941

# %%
df=pd.DataFrame(x)

# %%
df
# Out:
#             sp500
# 0     1295.500000
# 1     1289.089966
# 2     1293.670044
# 3     1308.040039
# 4     1314.500000
# ...           ...
# 2154  3327.770020
# 2155  3349.159912
# 2156  3351.280029
# 2157  3360.469971
# 2158  3333.689941
#
# [2159 rows x 1 columns]

# %%
df.head(4)
# Out:
#          sp500
# 0  1295.500000
# 1  1289.089966
# 2  1293.670044
# 3  1308.040039

# %%
df.tail(3)
# Out:
#             sp500
# 2156  3351.280029
# 2157  3360.469971
# 2158  3333.689941

# %%
df.sum()
# Out:
# sp500    4.790280e+06
# dtype: float64

# %%
df.product()
# Out:
# C:\Users\baliy\anaconda3\lib\site-packages\numpy\core\_methods.py:52: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# sp500    inf
# dtype: float64

# %%
import pandas as pd

# %%
df=pd.read_csv('Downloads\\bank_client_information.csv')
df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# ...

# %%
df["age"]=df['Net Worth']*2

# %%
df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank        age
# 0                5   10000.00
# 1                6   20000.00
# 2                7   18144.04
# 3               10   22144.04
# 4               22   10000.00
# ...

# %%
df.set_index("age",inplace=True)
df
# Out:
#           First Name Last Name                    Email Postal Code  \
# age
# 10000.00       Bird      Steve           bird@gmail.com     N94 3M0
# 20000.00        Noah     Small       nsmall@hotmail.com     N8S 14K
# 18144.04        Nina    Keller          azikez@gahew.mr     S1T 4E6
# 22144.04     Chanel      Steve         chanel@gmail.com     N7T 3E6
# 10000.00        Kate      Noor         kate@hotmail.com     K8N 5H6
# 200000.00      Samer        Mo          samer@gmail.com     J7H 3HY
# 100000.00       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8
# 40000.00       Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0
# 5258.26       Joseph    Patton           daafeja@boh.jm     M6U 5U7
# 17253.92        Noah     Moran        guutodi@bigwoc.kw     K2D 4M9
#
#            Net Worth  Years with Bank
# age
# 10000.00     5000.00                5
# 20000.00    10000.00                6
# 18144.04     9072.02                7
# 22144.04    11072.02               10
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#          age First Name Last Name                    Email Postal Code  \
# 0   10000.00      Bird      Steve           bird@gmail.com     N94 3M0
# 1   20000.00       Noah     Small       nsmall@hotmail.com     N8S 14K
# 2   18144.04       Nina    Keller          azikez@gahew.mr     S1T 4E6
# 3   22144.04    Chanel      Steve         chanel@gmail.com     N7T 3E6
# 4   10000.00       Kate      Noor         kate@hotmail.com     K8N 5H6
# 5  200000.00      Samer        Mo          samer@gmail.com     J7H 3HY
# 6  100000.00       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8
# 7   40000.00      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0
# 8    5258.26     Joseph    Patton           daafeja@boh.jm     M6U 5U7
# 9   17253.92       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9
#
#    Net Worth  Years with Bank
# 0    5000.00                5
# 1   10000.00                6
# 2    9072.02                7
# 3   11072.02               10
# 4    5000.00               22
# ...

# %%
f=df["Email"]

# %%
f
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
d=df["Net Worth"]

# %%
d
# Out:
# 0      5000.00
# 1     10000.00
# 2      9072.02
# 3     11072.02
# 4      5000.00
# 5    100000.00
# 6     50000.00
# 7     20000.00
# 8      2629.13
# 9      8626.96
# Name: Net Worth, dtype: float64

# %%
z=df[["Email",'age','Postal Code']]

# %%
z
# Out:
#                      Email        age Postal Code
# 0           bird@gmail.com   10000.00     N94 3M0
# 1       nsmall@hotmail.com   20000.00     N8S 14K
# 2          azikez@gahew.mr   18144.04     S1T 4E6
# 3         chanel@gmail.com   22144.04     N7T 3E6
# 4         kate@hotmail.com   10000.00     K8N 5H6
# 5          samer@gmail.com  200000.00     J7H 3HY
# 6  heba.ismail@hotmail.com  100000.00     K8Y 3M8
# 7      Laila.a@hotmail.com   40000.00     J8Y 3M0
# 8           daafeja@boh.jm    5258.26     M6U 5U7
# 9        guutodi@bigwoc.kw   17253.92     K2D 4M9

# %%
a=int(input("Enter the number: "))
b=[500,200,100,50,10,5,1]
x={}
for i in b:
    if a>=i:
        x[i]=a//i
        a=a%i
print(x)
# Out:
# Enter the number: 765
# {500: 1, 200: 1, 50: 1, 10: 1, 5: 1}

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Data+Analyst&txtLocation=Noida%2F+Greater+Noida%2CDelhi'
r=requests.get(url)

# %%
a=r.text

# %%
print(a)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <head>
#
#
#
# ...

# %%
soup=BeautifulSoup(a,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <head>
# ...

# %%
x=soup.find('li',class_='clearfix job-bx wht-shd-bx').text

# %%
print(x)
# Out:
# Data Analyst
#
#     Jio Saavan
#
#
#
#
# card_travel3 - 4 yrs
#
# location_on
# Gurgaon,  Mumbai,  Bengaluru / Bangalore
#
#
#
#
# Job Description:
# OUR CULTURE:At JioSaavn ,  we ignite passion and performance to work towards a collective goal: creating the perfect mobile entertainment ecosystem that delivers the best poss... More Details
#
#
# KeySkills:
#
# data mining  ,  dashboards  ,  sql  ,  advanced analytics  ,  data analysis  ,  mobile  ,  data analyst  ,  analytics reporting  ,  tableau
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago

# %%
v=soup.find('ul',class_='new-joblist').text

# %%
print(v)
# Out:
# Data Analyst
#
#     Jio Saavan
#
#
#
#
# card_travel3 - 4 yrs
#
# location_on
# Gurgaon,  Mumbai,  Bengaluru / Bangalore
#
#
#
#
# Job Description:
# OUR CULTURE:At JioSaavn ,  we ignite passion and performance to work towards a collective goal: creating the perfect mobile entertainment ecosystem that delivers the best poss... More Details
#
#
# KeySkills:
#
# data mining  ,  dashboards  ,  sql  ,  advanced analytics  ,  data analysis  ,  mobile  ,  data analyst  ,  analytics reporting  ,  tableau
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
# Data Analyst
#
#     ANR SOFTWARE PVT LTD
#
#
#
#
# card_travel0 - 1 yrs
#
# location_on
# Noida/Greater Noida
#
#
#
#
# Job Description:
# Data AnalystExperience: 0 to 1 YearsEligibility  &  Job Description Eligibility: Bachelor degree in Mathematics ,  Computer Science ,  Information Management or StatisticsAny ... More Details
#
#
# KeySkills:
#
# ...

# %%
z=soup.find('header',class_='clearfix').text

# %%
print(z)
# Out:
# 91 Job Found
# 91 Job Found
#
#
# Sort by freshness:
#
# Last 2 Months
# Last Month
# Last Week
# Last 3 days

# %%
z=soup.find('h3',class_='joblist-comp-name').text

# %%
print(z)
# Out:
#     Jio Saavan

# %%
d=soup.find('li',class_="clearfix job-bx wht-shd-bx").text

# %%
print(d)
# Out:
# Data Analyst
#
#     Jio Saavan
#
#
#
#
# card_travel3 - 4 yrs
#
# location_on
# Gurgaon,  Mumbai,  Bengaluru / Bangalore
#
#
#
#
# Job Description:
# OUR CULTURE:At JioSaavn ,  we ignite passion and performance to work towards a collective goal: creating the perfect mobile entertainment ecosystem that delivers the best poss... More Details
#
#
# KeySkills:
#
# data mining  ,  dashboards  ,  sql  ,  advanced analytics  ,  data analysis  ,  mobile  ,  data analyst  ,  analytics reporting  ,  tableau
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago

# %%
a=soup.find('h3',class_="joblist-comp-name").text

# %%
print(a)
# Out:
#     Jio Saavan

# %%
d=soup.find('ul',class_="top-jd-dtl clearfix").text

# %%
print(d)
# Out:
# card_travel3 - 4 yrs
#
# location_on
# Gurgaon,  Mumbai,  Bengaluru / Bangalore

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://opentender.eu/at/'
r=requests.get(url)

# %%
a=r.text

# %%
print(a)
# Out:
# <!DOCTYPE html><html lang="en"><head>
# 	<!-- Global site tag (gtag.js) - Google Analytics -->
# 	<!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NQSM6DP');</script>
# <!-- End Google Tag Manager -->
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta charset="utf-8">
# 	<title>Opentender Austria</title>
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<meta name="description" content="Opentender - Making Public Tenders More Transparent">
# 	<meta name="keywords" content="Open Data,Tender,Procurement">
# 	<meta name="author" content="digiwhist">
#
# ...

# %%
soup=BeautifulSoup(a,'html.parser')

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en"><head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NQSM6DP');</script>
# <!-- End Google Tag Manager -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <title>Opentender Austria</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Opentender - Making Public Tenders More Transparent" name="description"/>
# <meta content="Open Data,Tender,Procurement" name="keywords"/>
# <meta content="digiwhist" name="author"/>
# ...

# %%
x=soup.find('')

# %%
# Q6. Write a Python program to Initialize dictionary with default values

stu = ["Siva", "Sam", "Ram", "Pooja"]
defaults = {"designation": "Student", "Department": "BCA"}
 
result = dict.fromkeys(stu, defaults)
print(result)
 
# Individual data
print("\nSiva :",result["Siva"])
print("\nSam :",result["Sam"])
print("\nRam :",result["Ram"])
print("\nPooja :",result["Pooja"])
# Out:
# {'Siva': {'designation': 'Student', 'Department': 'BCA'}, 'Sam': {'designation': 'Student', 'Department': 'BCA'}, 'Ram': {'designation': 'Student', 'Department': 'BCA'}, 'Pooja': {'designation': 'Student', 'Department': 'BCA'}}
#
# Siva : {'designation': 'Student', 'Department': 'BCA'}
#
# Sam : {'designation': 'Student', 'Department': 'BCA'}
#
# Ram : {'designation': 'Student', 'Department': 'BCA'}
#
# Pooja : {'designation': 'Student', 'Department': 'BCA'}

# %%
Write a Python program to Rename key of a dictionary
Source Code
student = {
	"Name": "Tara",
	"RollNo":130046, 
	"Mark": 458, 
	"Age":16,
}
print("Before Rename Key of a Dictionary :",student)
student["Mark10"] = student.pop("Mark")
student["RegNo"] = student.pop("RollNo")
print("After Rename Key of a Dictionary :",student)

# %%
# Write a Python program to print the following floating numbers upto 2 decimal places
a = 84.4423
b = 23.36778
print("Original Value A : ", a)
print("Formatted Value A : "+"{:.2f}".format(a));
print("Original Value B : ", b)
print("Formatted Value B : "+"{:.2f}".format(b));
print()
# Out:
# Original Value A :  84.4423
# Formatted Value A : 84.44
# Original Value B :  23.36778
# Formatted Value B : 23.37

# %%
#Write a Python program to print the following integers with zeros on the left of specified width
Source Code
a = 23
b = 833
print("\nOriginal Number: ", a)
print("Formatted Number(left padding, width 2): "+"{:0>2d}".format(a));
print("Original Number: ", b)
print("Formatted Number(left padding, width 6): "+"{:0>6d}".format(b));

# %%
a = [1,2,3,4,5,6,7,8]
b = [11,2,43,48,55,6,76,8]
x=set(a)
y=set(b)
n=x.intersection(y)

# %%
a=list(n)

# %%
a
# Out:
# [8, 2, 6]

# %%
# Create a sequence of numbers using range, then ask the user to enter a number. Inform the user whether or not their number was within the range you specified

# %%
val = {'T', 'u', 't', 'o', 'r', 'J', 'o', 'e' , 's'}
print(val)
print(type(val))
 
print("\nConvert Set Into List\n")
s = list(val)
print(s)
print(type(s))
# Out:
# {'J', 'r', 't', 'u', 's', 'o', 'T', 'e'}
# <class 'set'>
#
# Convert Set Into List
#
# ['J', 'r', 't', 'u', 's', 'o', 'T', 'e']
# <class 'list'>

# %%
val = {'T', 'u', 't', 'o', 'r', 'J', 'o', 'e' , 's'}
print(val)
# Out:
# {'J', 'r', 't', 'u', 's', 'o', 'T', 'e'}

# %%
str = "Tuton/nJoes/nCompute name/nEducation"
print(str.split('/n'))
# Out:
# ['Tuton', 'Joes', 'Compute name', 'Education']

# %%
#Write a Python program to print the following floating numbers with no decimal places

a =23.36778
b =-74.99
print("Original Value A : ", a)
print("Formatted Value no decimal places A : "+"{:.0f}".format(a));
print("Original Value B : ", b)
print("Formatted Value no decimal places B : "+"{:.0f}".format(b));
# Out:
# Original Value A :  23.36778
# Formatted Value no decimal places A : 23
# Original Value B :  -74.99
# Formatted Value no decimal places B : -75

# %%
#Write a Python program to check whether a string starts with specified characters
r = "Tutor Joes Computer Education"
print(str.startswith("Tu"))
print(str.startswith("tur"))
# Out:
# False
# False

# %%
# Write a Python function to reverses a string if its length is a multiple of 6

str=input("Enter the String :")
if len(str) % 4 == 0:
   print(''.join(reversed(str)))
else:
	print(str)
# Out:
# Enter the String :jhkl
# lkhj

# %%
# Out:
# Before Swap : abc   xyz
# After Swap : xyc   abz

# %%
# Out:
# Given String : tutor joes Ksa lga test Mitro
# After String : tutor joes Ksa lga test Mitro
