# %%
import pandas as pd

# %%
x=pd.read_csv("Downloads\\netflix_titles.csv")
x
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
x.head(5) # To show the top x record od the data set
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
x.tail() # To show the x lowest record of the dataset
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
x.shape    #To show the no. of Rows and Columns
# Out:
# (8807, 12)

# %%
x.size     #To show the number of values in the dataset
# Out:
# 105684

# %%
x.columns   #To show each columns in the dataset
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
x.dtypes     #To show the data type of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
x.info()                  #To show every information of the data set like undexs,columns etc...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
x[x.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
x.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
x.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # Seaborn(Heat Map)

# %%
import seaborn as sns

# %% [markdown]
# # Using Heat Map to show null values count

# %%
sns.heatmap(x.isnull())
# Out:
# <AxesSubplot:>

# %%
x[x['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
x[x['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
a=pd.read_excel('Downloads\\SQL Assignment.xlsx')

# %%
a
# Out:
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0          NaN                                                NaN         NaN
# 1          NaN                                         Question -         NaN
# 2          NaN  There are two campaigns running campaign A and...         NaN
# 3          NaN                      1. Participated in campaign A         NaN
# 4          NaN                       2. Paticipated in campaign B         NaN
# 5          NaN                   3. Patcipated in campaign A only         NaN
# 6          NaN                 4. Participated in campaign B only         NaN
# 7          NaN              5. Participated in both the campaigns         NaN
# 8          NaN  6. Participated in either campaign A or Campai...         NaN
# 9          NaN                                                NaN         NaN
# 10         NaN                                                NaN         NaN
# ...

# %%
a.isnull().sum()
# Out:
# Unnamed: 0    48
# Unnamed: 1    40
# Unnamed: 2    12
# Unnamed: 3    48
# Unnamed: 4    48
# Unnamed: 5    17
# dtype: int64

# %%
a=pd.read_excel('OneDrive\\Desktop\\sekufsferdvedvd.xlsx',header=None,prefix=)
# Out:
#   Input In [20]
#     a=pd.read_excel('OneDrive\\Desktop\\sekufsferdvedvd.xlsx',header=None,prefix=)
#                                                                                  ^
# SyntaxError: invalid syntax

# %%
a

# %%
u=pd.merge(a,d)

# %%
u

# %%
x=pd.read_excel("OneDrive\\Desktop\\iuwegabckshc.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 x=pd.read_excel("OneDrive\\Desktop\\iuwegabckshc.xlsx")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
x

# %%
d=pd.read_csv('OneDrive\\Desktop\\raviiiiiiii.csv')

# %%
d

# %%
s=pd.merge(d,x)

# %%
import pandas as pd

# %%
x=pd.read_csv("Downloads\\ecommerce_sales.csv",encoding="unicode_escape")

# %%
x
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
h=[]
for i in x['InvoiceDate']:
    d=i[0:2]+'-'+i[3:4]+'-'+i[5:]
    h.append(d)
del x['InvoiceDate']
x.insert(4,'InvoiceDate',h)
x
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                                               InvoiceDate  UnitPrice  \
# ...

# %%
import pandas as pd
x=pd.read_csv("Downloads\\ecommerce_sales.csv",encoding="unicode_escape")
x
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
import json

# %%
l='[1,2,3,4]'
x=json.loads(l)

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
print(len(r'1\n2\t3\b'))
# Out:
# 9

# %%
def f(x,arr=[]):
    arr.append(x)
    return arr
print(f(1),f(2))
# Out:
# [1, 2] [1, 2]

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
print('some'+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 print('some'+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(all([i for i in range(1)]))
# Out:
# False

# %%
import pandas as pd
import numpy as np

# %%
d=np.array(['apple','bana',"c",'d'])
s=pd.series(d,index=[1,2,3,4])
print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 d=np.array(['apple','bana',"c",'d'])
# ----> 2 s=pd.series(d,index=[1,2,3,4])
#       3 print(s)
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
pd.read_avro()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 pd.read_avro()
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_avro'

# %%
pd.read_table()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 pd.read_table()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_table() missing 1 required positional argument: 'filepath_or_buffer'

# %%
print(np.var([1,2,3,4]))
# Out:
# 1.25

# %%
x=np.linspace(2,3,4, retstep=True)
print(x)
# Out:
# (array([2.        , 2.33333333, 2.66666667, 3.        ]), 0.3333333333333333)

# %%
f=lamda x: sum([i*i for i in range(1,x+!)])
    print(f(5))
# Out:
#   Input In [20]
#     f=lamda x: sum([i*i for i in range(1,x+!)])
#             ^
# SyntaxError: invalid syntax

# %%
x,y=1,1
def f():
    global x
    y=0
    for i in (10,20,30):
        x+=1
        y+=1
f()
print(x,y)
# Out:
# 4 1

# %%
t=['hi','hey','hello']
print(map(lambda x: len(x),l))

# %%
print('a' and 'b' and 'c')
# Out:
# c

# %%
import pandas as pd

# %%
x=pd.read_csv("Downloads\\avocado (1).csv")

# %%
x
# Out:
#              Date  AveragePrice  Total Volume          type            region
# 0      12/27/2015          1.33      64236.62  conventional            Albany
# 1      12/20/2015          1.35      54876.98  conventional            Albany
# 2      12/13/2015          0.93     118220.22  conventional            Albany
# 3       12/6/2015          1.08      78992.15  conventional            Albany
# 4      11/29/2015          1.28      51039.60  conventional            Albany
# ...           ...           ...           ...           ...               ...
# 18244    2/4/2018          1.63      17074.83       organic  WestTexNewMexico
# 18245   1/28/2018          1.71      13888.04       organic  WestTexNewMexico
# 18246   1/21/2018          1.87      13766.76       organic  WestTexNewMexico
# 18247   1/14/2018          1.93      16205.22       organic  WestTexNewMexico
# 18248    1/7/2018          1.62      17489.58       organic  WestTexNewMexico
#
# [18249 rows x 5 columns]

# %%
x.iloc(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 x.iloc(3)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:634, in _LocationIndexer.__call__(self, axis)
#     631 new_self = type(self)(self.name, self.obj)
#     633 if axis is not None:
# --> 634     axis = self.obj._get_axis_number(axis)
#     635 new_self.axis = axis
#     636 return new_self
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:552, in NDFrame._get_axis_number(cls, axis)
# ...
